# %% [markdown]
# #  Descripción del análisis de causas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#PROM_VEL_HOGAR

# %%
data.columns
# Out:
# Index(['CUENTA', 'COD_SERVICIO', 'Velocidad', 'Internet', 'COD_NODO',
#        'ESTRATO', 'CARTERA', 'CONGELACION', 'VIAJES', 'CAPACIDAD_DE_PAGO',
#        'CAUSAS_EXTERNAS', 'COMPETENCIA', 'MAL_SERVICIO', 'NO_UTILIZAR',
#        'NO_GUSTO', 'SIN_MOTIVO', 'SIN_CONTACTO', 'TRASLADOS', 'OTROS',
#        'CD_BLANCOS_CAMBIOS_OTROS', 'CAMBIO_DE_SERVICIO', 'CAMBIO_TARIFA',
#        'EMPAQUETAMIENTO', 'CESION_DE_CONTRATO', 'UNIFICACION_EMPAQUETAMIENTO',
#        'CD_BLANCOS_CAMBIOS_SERVICIO', 'FECHA', 'CHURN_TEMPRANO',
#        'INVOLUNTARIO', 'VOLUNTARIO', 'TIPO_RAZON', 'CANTIDAD_LLAMADAS',
#        'CANTIDAD_ADMIN', 'CANTIDAD_TECNICO', 'CAMPANA_HBO', 'CAMPANA_FOX',
#        'CAMPANA_ADULTO', 'CAMPANA_EQUIPOS_ADIC', 'CAMPANA_ULTRAWIFI',
#        'CAMPANA_VOZ', 'CAMPANA_RETENCION', 'CAMPANA_AFECTACION_SRV',
#        'PART_CANT_CALL', 'CANT_USER', 'PROM_VEL', 'VEL_ME_8', 'VEL_10_25',
#        'VEL_30', 'VEL_40_50', 'VEL_MA_60', 'CONVERGENTE', 'PROM_VEL_HOGAR',
#        'MEDIANA_VEL', 'PROM_RENTA', 'PRECIO_MEGA_CLARO_1', 'CANTIDAD_churn',
#        'ANTIGUEDAD_MESES_PROM', 'ANTIGUEDAD_MESES_MED', 'AVG_TARIFA_TIGO',
#        'AVG_TIGO_MEGAS', 'PRECIO_MEGA_TIGO_1', 'AVG_TARIFA_ETB',
#        'AVG_ETB_MEGAS', 'PRECIO_MEGA_ETB_1', 'AVG_TARIFA_MOVISTAR',
#        'AVG_MOVISTAR_MEGAS', 'AVG_MOV_MEGAS', 'OPERADOR_TIGO_OOKLA',
#        'OPERADOR_ETB_OOKLA', 'OPERADOR_MOVISTAR_OOKLA', 'SUMA_OPERADORES',
#        'RANK1_VEL_DWLD', 'OP_CLARO', 'CANTIDAD', 'PENETRACION', 'OCUPACION_DW',
#        'OCUPACION_UP', 'ALFA', 'BETA', 'MEGA', 'NIVEL_ALARMA_MALO',
#        'NIVEL_ALARMA_BUENO', 'DIVISION', 'AREA', 'ZONA', 'CIUDAD', 'DISTRITO',
#        'BAJAS TOTAL'],
#       dtype='object')

# %%
data= pd.read_csv('DATA_FINAL_08.csv',sep=';', header = 0)
# Out:
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (3,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data['CARTERA']=np.where(data['CARTERA']=='0',0,data['CARTERA'])

# %%
data['INVOLUNTARIO']=np.where(data['CARTERA']==0,0,-1)
data['VOLUNTARIO']=np.where(data['CARTERA']==0,-1,0)

# %%
seleccionVariables=['CONGELACION','VIAJES','CAPACIDAD_DE_PAGO','CAUSAS_EXTERNAS','COMPETENCIA','MAL_SERVICIO','NO_UTILIZAR',
                    'NO_GUSTO','SIN_MOTIVO','SIN_CONTACTO','TRASLADOS','OTROS','CAMBIO_DE_SERVICIO','CAMBIO_TARIFA','EMPAQUETAMIENTO',
                    'CESION_DE_CONTRATO','UNIFICACION_EMPAQUETAMIENTO']

# %%
data['BAJAS_TOTAL']=data[seleccionVariables].sum(axis=1)

# %%
data.dtypes
# Out:
# CUENTA           int64
# COD_SERVICIO    object
# Velocidad       object
# Internet        object
# COD_NODO        object
#                  ...
# AREA            object
# ZONA            object
# CIUDAD          object
# DISTRITO        object
# BAJAS_TOTAL      int64
# Length: 88, dtype: object

# %% [markdown]
# ### Corrrelaciones

# %% [markdown]
# ### Pearson

# %%
# para ver el grado de correlación entre las variables disponibles.
def tidy_corr_matrix(corr_mat):
    '''
    Función para convertir una matrix de correlación de pandas en formato tidy
    '''
    corr_mat = corr_mat.stack().reset_index()
    corr_mat.columns = ['variable_1','variable_2','r']
    corr_mat = corr_mat.loc[corr_mat['variable_1'] != corr_mat['variable_2'], :]
    corr_mat['abs_r'] = np.abs(corr_mat['r'])
    corr_mat = corr_mat.sort_values('abs_r', ascending=False)
    
    return(corr_mat)

corr_matrix = data.select_dtypes(include=['float64', 'int','int64']).corr(method='pearson')
# Out:
#                  variable_1             variable_2         r     abs_r
# 2619  ANTIGUEDAD_MESES_PROM   ANTIGUEDAD_MESES_MED  1.000000  1.000000
# 2683   ANTIGUEDAD_MESES_MED  ANTIGUEDAD_MESES_PROM  1.000000  1.000000
# 1034           INVOLUNTARIO             VOLUNTARIO -1.000000  1.000000
# 1101             VOLUNTARIO           INVOLUNTARIO -1.000000  1.000000
# 2281         PROM_VEL_HOGAR               PROM_VEL  0.993246  0.993246
# 1833               PROM_VEL         PROM_VEL_HOGAR  0.993246  0.993246
# 3075      PRECIO_MEGA_ETB_1          AVG_ETB_MEGAS -0.986750  0.986750
# 3011          AVG_ETB_MEGAS      PRECIO_MEGA_ETB_1 -0.986750  0.986750
# 3203     AVG_MOVISTAR_MEGAS          AVG_ETB_MEGAS  0.972205  0.972205
# 3013          AVG_ETB_MEGAS     AVG_MOVISTAR_MEGAS  0.972205  0.972205

# %%
corr_tab=tidy_corr_matrix(corr_matrix)

# %%
corr_tab=corr_tab[corr_tab['variable_2']=='BAJAS_TOTAL'].drop(columns=['variable_2'])

# %%
corr_tab['abs_r'].describe()
# Out:
# count    67.000000
# mean      0.068908
# std       0.107448
# min       0.000372
# 25%       0.014873
# 50%       0.030414
# 75%       0.062866
# max       0.648231
# Name: abs_r, dtype: float64

# %%
corr_tab[corr_tab['abs_r']>=0.06].sort_values('r')
# Out:
#              variable_1         r     abs_r
# 1287     CANTIDAD_ADMIN -0.248793  0.248793
# 1219  CANTIDAD_LLAMADAS -0.181563  0.181563
# 2579     CANTIDAD_churn -0.109958  0.109958
# 2384        MEDIANA_VEL -0.081629  0.081629
# 1083       INVOLUNTARIO -0.080269  0.080269
# 1419        CAMPANA_HBO -0.068197  0.068197
# 1151         VOLUNTARIO  0.080269  0.080269
# 702        SIN_CONTACTO  0.094646  0.094646
# 770               OTROS  0.117573  0.117573
# 566            NO_GUSTO  0.158246  0.158246
# 362         COMPETENCIA  0.181455  0.181455
# 203              VIAJES  0.193676  0.193676
# 498         NO_UTILIZAR  0.208448  0.208448
# 430        MAL_SERVICIO  0.310002  0.310002
# 135         CONGELACION  0.337501  0.337501
# 271   CAPACIDAD_DE_PAGO  0.340754  0.340754
# 634          SIN_MOTIVO  0.648231  0.648231

# %%
corr_tab_graf=corr_tab[corr_tab['abs_r']>=0.06].set_index('variable_1')

# %%
corr_tab_graf.drop(columns=['abs_r'],inplace=True)
corr_tab_graf.columns=['BAJAS_TOTAL']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-165-410529f7bfb8> in <module>
# ----> 1 corr_tab_graf.drop(columns=['abs_r'],inplace=True)
#       2 corr_tab_graf.columns=['BAJAS_TOTAL']
#       3 corr_tab_graf
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['abs_r'] not found in axis"

# %%
corr_tab_graf.sort_values('BAJAS_TOTAL')
# Out:
#                    BAJAS_TOTAL
# variable_1
# CANTIDAD_ADMIN       -0.248793
# CANTIDAD_LLAMADAS    -0.181563
# CANTIDAD_churn       -0.109958
# MEDIANA_VEL          -0.081629
# INVOLUNTARIO         -0.080269
# CAMPANA_HBO          -0.068197
# VOLUNTARIO            0.080269
# SIN_CONTACTO          0.094646
# OTROS                 0.117573
# NO_GUSTO              0.158246
# COMPETENCIA           0.181455
# VIAJES                0.193676
# NO_UTILIZAR           0.208448
# MAL_SERVICIO          0.310002
# CONGELACION           0.337501
# CAPACIDAD_DE_PAGO     0.340754
# SIN_MOTIVO            0.648231

# %%
corr_matrix.columns
# Out:
# Index(['CUENTA', 'CONGELACION', 'VIAJES', 'CAPACIDAD_DE_PAGO',
#        'CAUSAS_EXTERNAS', 'COMPETENCIA', 'MAL_SERVICIO', 'NO_UTILIZAR',
#        'NO_GUSTO', 'SIN_MOTIVO', 'SIN_CONTACTO', 'TRASLADOS', 'OTROS',
#        'CD_BLANCOS_CAMBIOS_OTROS', 'CAMBIO_DE_SERVICIO', 'CAMBIO_TARIFA',
#        'EMPAQUETAMIENTO', 'CESION_DE_CONTRATO', 'UNIFICACION_EMPAQUETAMIENTO',
#        'CD_BLANCOS_CAMBIOS_SERVICIO', 'FECHA', 'CHURN_TEMPRANO',
#        'INVOLUNTARIO', 'VOLUNTARIO', 'CANTIDAD_LLAMADAS', 'CANTIDAD_ADMIN',
#        'CANTIDAD_TECNICO', 'CAMPANA_HBO', 'CAMPANA_FOX', 'CAMPANA_ADULTO',
#        'CAMPANA_EQUIPOS_ADIC', 'CAMPANA_ULTRAWIFI', 'CAMPANA_VOZ',
#        'CAMPANA_RETENCION', 'CAMPANA_AFECTACION_SRV', 'PART_CANT_CALL',
#        'CANT_USER', 'PROM_VEL', 'VEL_ME_8', 'VEL_10_25', 'VEL_30', 'VEL_40_50',
#        'VEL_MA_60', 'CONVERGENTE', 'PROM_VEL_HOGAR', 'MEDIANA_VEL',
#        'PROM_RENTA', 'PRECIO_MEGA_CLARO_1', 'CANTIDAD_churn',
#        'ANTIGUEDAD_MESES_PROM', 'ANTIGUEDAD_MESES_MED', 'AVG_TARIFA_TIGO',
#        'AVG_TIGO_MEGAS', 'PRECIO_MEGA_TIGO_1', 'AVG_TARIFA_ETB',
#        'AVG_ETB_MEGAS', 'PRECIO_MEGA_ETB_1', 'AVG_TARIFA_MOVISTAR',
#        'AVG_MOVISTAR_MEGAS', 'AVG_MOV_MEGAS', 'OPERADOR_TIGO_OOKLA',
#        'OPERADOR_ETB_OOKLA', 'OPERADOR_MOVISTAR_OOKLA', 'SUMA_OPERADORES',
#        'RANK1_VEL_DWLD', 'OP_CLARO', 'CANTIDAD', 'PENETRACION', 'OCUPACION_DW',
#        'OCUPACION_UP', 'ALFA', 'BETA', 'MEGA', 'NIVEL_ALARMA_MALO',
#        'NIVEL_ALARMA_BUENO', 'BAJAS_TOTAL'],
#       dtype='object')

# %%
corr_matrix
variables_y=['CONGELACION','VIAJES','CAPACIDAD_DE_PAGO','CAUSAS_EXTERNAS','COMPETENCIA','MAL_SERVICIO','NO_UTILIZAR',
                    'NO_GUSTO','SIN_MOTIVO','SIN_CONTACTO','TRASLADOS','OTROS','CAMBIO_DE_SERVICIO','CAMBIO_TARIFA','EMPAQUETAMIENTO',
                    'CESION_DE_CONTRATO','UNIFICACION_EMPAQUETAMIENTO']
variables_x=list(set(corr_matrix.columns) - set(variables_y))

# %%
variables_x.remove('CUENTA')
variables_x.remove('CD_BLANCOS_CAMBIOS_SERVICIO')
variables_x.remove('FECHA')
variables_x.remove('BAJAS_TOTAL')
#variables_x.remove('CD_BLANCOS_CAMBIOS_SERVICIO')

# %%
variables_y.remove('CAMBIO_DE_SERVICIO')
variables_y.remove('TRASLADOS')
variables_y.remove('EMPAQUETAMIENTO')
variables_y.remove('CESION_DE_CONTRATO')
#variables_y.remove('CD_BLANCOS_CAMBIOS_SERVICIO')

# %%
corr_matrix_V2=corr_matrix.copy()[variables_y]

# %%
corr_matrix_V2=corr_matrix_V2[corr_matrix_V2.index.isin(variables_x)]

# %%
def _color_red_or_green(val):
    color = 'red' if val < 0 else 'green'
    return 'color: %s' % color

# %%
def highlight_max(s, props=''):
    return np.where(s == np.nanmax(s.values), props, '')

# %%
corr_matrix_V2
# Out:
#                           CONGELACION    VIAJES  CAPACIDAD_DE_PAGO  \
# CD_BLANCOS_CAMBIOS_OTROS    -0.000423 -0.000251          -0.000439
# CHURN_TEMPRANO              -0.003245  0.015487           0.022160
# INVOLUNTARIO                 0.062085 -0.022759          -0.048930
# VOLUNTARIO                  -0.062085  0.022759           0.048930
# CANTIDAD_LLAMADAS           -0.015242 -0.026354          -0.068625
# CANTIDAD_ADMIN              -0.032052 -0.039272          -0.100302
# CANTIDAD_TECNICO             0.012182 -0.001319          -0.005467
# CAMPANA_HBO                  0.000562  0.000539           0.001232
# CAMPANA_FOX                       NaN       NaN                NaN
# CAMPANA_ADULTO               0.000398  0.000381           0.000871
# CAMPANA_EQUIPOS_ADIC         0.018337  0.013515           0.019661
# CAMPANA_ULTRAWIFI                 NaN       NaN                NaN
# CAMPANA_VOZ                 -0.009600 -0.004673          -0.012077
# CAMPANA_RETENCION            0.015720  0.008608           0.007759
# CAMPANA_AFECTACION_SRV            NaN       NaN                NaN
# PART_CANT_CALL               0.008978  0.002994          -0.003732
# CANT_USER                   -0.001768  0.003901          -0.009779
# PROM_VEL                     0.001481 -0.031450          -0.005221
# VEL_ME_8                     0.002739  0.011863          -0.006346
# VEL_10_25                   -0.008507  0.013032          -0.005104
# VEL_30                       0.000166  0.014096          -0.003550
# VEL_40_50                   -0.015259  0.006513          -0.004510
# VEL_MA_60                    0.005358 -0.017790          -0.009871
# CONVERGENTE                 -0.008669  0.000110          -0.009368
# PROM_VEL_HOGAR               0.001555 -0.031097          -0.005467
# MEDIANA_VEL                 -0.009036 -0.036308          -0.011765
# PROM_RENTA                  -0.010275 -0.022475           0.008358
# PRECIO_MEGA_CLARO_1         -0.014496  0.016892           0.001275
# CANTIDAD_churn               0.002599 -0.018601          -0.034233
# ANTIGUEDAD_MESES_PROM       -0.001993 -0.009335          -0.003735
# ANTIGUEDAD_MESES_MED        -0.001993 -0.009335          -0.003735
# AVG_TARIFA_TIGO             -0.007908 -0.015172          -0.004261
# AVG_TIGO_MEGAS              -0.004226 -0.011906          -0.004728
# PRECIO_MEGA_TIGO_1           0.001818 -0.003599          -0.004956
# AVG_TARIFA_ETB              -0.003151 -0.022739          -0.002638
# AVG_ETB_MEGAS               -0.000590 -0.021395           0.001094
# PRECIO_MEGA_ETB_1           -0.000486 -0.002384          -0.010472
# AVG_TARIFA_MOVISTAR          0.002704  0.009014           0.001734
# AVG_MOVISTAR_MEGAS          -0.004257 -0.020708          -0.010538
# AVG_MOV_MEGAS               -0.002314 -0.008587          -0.010142
# OPERADOR_TIGO_OOKLA          0.007382  0.001390          -0.000555
# OPERADOR_ETB_OOKLA          -0.005266 -0.002364          -0.001493
# OPERADOR_MOVISTAR_OOKLA     -0.000858 -0.003402          -0.002909
# SUMA_OPERADORES              0.001271 -0.001986          -0.002396
# RANK1_VEL_DWLD               0.000611 -0.022230          -0.002038
# OP_CLARO                     0.006477  0.011616           0.002967
# CANTIDAD                     0.005133  0.002093           0.001147
# PENETRACION                 -0.000307 -0.005478           0.000245
# OCUPACION_DW                -0.002182  0.002176          -0.013010
# OCUPACION_UP                -0.004721 -0.003776          -0.009246
# ALFA                        -0.003919 -0.007480          -0.002204
# BETA                        -0.001587 -0.003543          -0.001884
# MEGA                        -0.003856 -0.008741          -0.000901
# NIVEL_ALARMA_MALO            0.003322 -0.004026          -0.001783
# NIVEL_ALARMA_BUENO           0.009939 -0.017103          -0.007836
#
#                           CAUSAS_EXTERNAS  COMPETENCIA  MAL_SERVICIO  \
# CD_BLANCOS_CAMBIOS_OTROS         0.003235    -0.000235     -0.000401
# CHURN_TEMPRANO                   0.007249     0.015962      0.020613
# INVOLUNTARIO                     0.051158    -0.026900     -0.043717
# VOLUNTARIO                      -0.051158     0.026900      0.043717
# CANTIDAD_LLAMADAS               -0.011448    -0.029739     -0.108396
# CANTIDAD_ADMIN                  -0.016404    -0.041942     -0.113602
# CANTIDAD_TECNICO                -0.000882    -0.004478     -0.065645
# CAMPANA_HBO                           NaN     0.000660     -0.100182
# CAMPANA_FOX                           NaN          NaN           NaN
# CAMPANA_ADULTO                        NaN     0.000467      0.000776
# CAMPANA_EQUIPOS_ADIC                  NaN    -0.000838     -0.017459
# CAMPANA_ULTRAWIFI                     NaN          NaN           NaN
# CAMPANA_VOZ                           NaN     0.000744      0.022746
# CAMPANA_RETENCION                     NaN    -0.004218     -0.002921
# CAMPANA_AFECTACION_SRV                NaN          NaN           NaN
# PART_CANT_CALL                        NaN    -0.000349      0.005249
# CANT_USER                             NaN     0.003530     -0.000886
# PROM_VEL                              NaN    -0.017951     -0.033365
# VEL_ME_8                              NaN     0.010140      0.015732
# VEL_10_25                             NaN     0.007621      0.013569
# VEL_30                                NaN     0.009459      0.013479
# VEL_40_50                             NaN     0.000247     -0.000926
# VEL_MA_60                             NaN    -0.008310     -0.023977
# CONVERGENTE                           NaN    -0.001223     -0.009795
# PROM_VEL_HOGAR                        NaN    -0.017935     -0.033665
# MEDIANA_VEL                           NaN    -0.022042     -0.038662
# PROM_RENTA                            NaN    -0.016982     -0.024220
# PRECIO_MEGA_CLARO_1                   NaN     0.007039      0.019333
# CANTIDAD_churn                        NaN    -0.029987     -0.045711
# ANTIGUEDAD_MESES_PROM                 NaN    -0.011829     -0.017493
# ANTIGUEDAD_MESES_MED                  NaN    -0.011829     -0.017493
# AVG_TARIFA_TIGO                       NaN    -0.014314     -0.021936
# AVG_TIGO_MEGAS                        NaN    -0.001108     -0.003551
# PRECIO_MEGA_TIGO_1                    NaN    -0.008039     -0.014403
# AVG_TARIFA_ETB                        NaN    -0.006937     -0.018064
# AVG_ETB_MEGAS                         NaN    -0.004106     -0.012713
# PRECIO_MEGA_ETB_1                     NaN    -0.006206     -0.017240
# AVG_TARIFA_MOVISTAR                   NaN    -0.000644     -0.000834
# AVG_MOVISTAR_MEGAS                    NaN    -0.004829     -0.015653
# AVG_MOV_MEGAS                         NaN    -0.009203     -0.019356
# OPERADOR_TIGO_OOKLA                   NaN    -0.001691     -0.001068
# OPERADOR_ETB_OOKLA                    NaN    -0.004598     -0.014638
# OPERADOR_MOVISTAR_OOKLA               NaN    -0.007470     -0.007178
# SUMA_OPERADORES                       NaN    -0.006606     -0.010250
# RANK1_VEL_DWLD                        NaN    -0.018978     -0.028854
# OP_CLARO                              NaN     0.013712      0.020628
# CANTIDAD                              NaN     0.000942      0.003591
# PENETRACION                           NaN     0.000200      0.000121
# OCUPACION_DW                          NaN     0.001252     -0.003665
# OCUPACION_UP                          NaN    -0.003095     -0.009721
# ALFA                                  NaN    -0.009148     -0.012502
# BETA                                  NaN    -0.002414     -0.003813
# MEGA                                  NaN    -0.014372     -0.017158
# NIVEL_ALARMA_MALO                     NaN    -0.001251     -0.004665
# NIVEL_ALARMA_BUENO                    NaN    -0.004046     -0.010936
#
#                           NO_UTILIZAR  NO_GUSTO  SIN_MOTIVO  SIN_CONTACTO  \
# CD_BLANCOS_CAMBIOS_OTROS    -0.000269 -0.000203   -0.000837      0.028966
# CHURN_TEMPRANO               0.015039  0.009106    0.033587      0.012245
# INVOLUNTARIO                -0.014471 -0.016426   -0.094658      0.087639
# VOLUNTARIO                   0.014471  0.016426    0.094658     -0.087639
# CANTIDAD_LLAMADAS           -0.035593 -0.044649   -0.112885     -0.020876
# CANTIDAD_ADMIN              -0.052431 -0.060359   -0.161860     -0.026938
# CANTIDAD_TECNICO            -0.002087 -0.009640   -0.013130     -0.005374
# CAMPANA_HBO                  0.000638  0.000565   -0.046621      0.000170
# CAMPANA_FOX                       NaN       NaN         NaN           NaN
# CAMPANA_ADULTO               0.000451  0.000400    0.001712      0.000120
# CAMPANA_EQUIPOS_ADIC         0.008793  0.008760    0.015599      0.008759
# CAMPANA_ULTRAWIFI                 NaN       NaN         NaN           NaN
# CAMPANA_VOZ                 -0.004192 -0.006412    0.013722     -0.006484
# CAMPANA_RETENCION            0.010188  0.000411    0.022829      0.002721
# CAMPANA_AFECTACION_SRV            NaN       NaN         NaN           NaN
# PART_CANT_CALL               0.000870  0.000093    0.000227     -0.000174
# CANT_USER                   -0.002504 -0.000876    0.001448     -0.000493
# PROM_VEL                    -0.015030 -0.006805   -0.039038     -0.000265
# VEL_ME_8                     0.002420  0.002551    0.013294      0.000339
# VEL_10_25                    0.004799  0.001848    0.007664      0.000023
# VEL_30                       0.004636  0.002356    0.018398     -0.000314
# VEL_40_50                    0.002124 -0.002626    0.003707     -0.000681
# VEL_MA_60                   -0.012782 -0.004114   -0.023866     -0.000656
# CONVERGENTE                 -0.005090 -0.003270   -0.001182     -0.000198
# PROM_VEL_HOGAR              -0.014869 -0.006938   -0.038302     -0.000088
# MEDIANA_VEL                 -0.018804 -0.010087   -0.056589     -0.000056
# PROM_RENTA                  -0.002243 -0.004812   -0.020994     -0.000403
# PRECIO_MEGA_CLARO_1          0.009719  0.001904    0.010916     -0.000171
# CANTIDAD_churn              -0.018490 -0.015067   -0.088095     -0.000443
# ANTIGUEDAD_MESES_PROM       -0.003212 -0.003894   -0.022296     -0.000527
# ANTIGUEDAD_MESES_MED        -0.003212 -0.003894   -0.022296     -0.000527
# AVG_TARIFA_TIGO             -0.000290 -0.005037   -0.031150     -0.000809
# AVG_TIGO_MEGAS              -0.012734 -0.000725   -0.020056     -0.000863
# PRECIO_MEGA_TIGO_1           0.001647 -0.005934   -0.009093      0.000034
# AVG_TARIFA_ETB              -0.013340 -0.001982   -0.042381     -0.001031
# AVG_ETB_MEGAS               -0.011922 -0.000113   -0.036108     -0.000714
# PRECIO_MEGA_ETB_1           -0.006514 -0.006191   -0.001126     -0.000392
# AVG_TARIFA_MOVISTAR          0.010894 -0.000128    0.010908      0.000593
# AVG_MOVISTAR_MEGAS          -0.017782 -0.002954   -0.039698     -0.000897
# AVG_MOV_MEGAS               -0.003550 -0.007230   -0.021459     -0.000603
# OPERADOR_TIGO_OOKLA          0.000754 -0.000830   -0.011098     -0.002058
# OPERADOR_ETB_OOKLA          -0.001397 -0.003011    0.007483     -0.000116
# OPERADOR_MOVISTAR_OOKLA     -0.001726 -0.001690   -0.021447     -0.002007
# SUMA_OPERADORES             -0.001063 -0.002538   -0.013751     -0.002156
# RANK1_VEL_DWLD              -0.007650 -0.005541   -0.033135      0.000148
# OP_CLARO                     0.004088  0.005427    0.020277     -0.000740
# CANTIDAD                     0.001233  0.001482   -0.003998     -0.001765
# PENETRACION                  0.000106  0.000137    0.001021     -0.000017
# OCUPACION_DW                -0.004275 -0.003802   -0.006342     -0.000057
# OCUPACION_UP                -0.004560 -0.003833   -0.006904     -0.000506
# ALFA                        -0.001693 -0.003016   -0.015961      0.000106
# BETA                        -0.001221 -0.001006   -0.005452      0.000082
# MEGA                        -0.000957 -0.003735   -0.021389      0.000087
# NIVEL_ALARMA_MALO           -0.003277 -0.000464   -0.007547      0.000210
# NIVEL_ALARMA_BUENO          -0.012721 -0.001633   -0.035640     -0.001731
#
#                              OTROS  CAMBIO_TARIFA  UNIFICACION_EMPAQUETAMIENTO
# CD_BLANCOS_CAMBIOS_OTROS -0.000139       0.007460                    -0.000026
# CHURN_TEMPRANO            0.006693       0.002792                     0.002688
# INVOLUNTARIO             -0.005862       0.019701                     0.016519
# VOLUNTARIO                0.005862      -0.019701                    -0.016519
# CANTIDAD_LLAMADAS        -0.018653      -0.011273                    -0.001725
# CANTIDAD_ADMIN           -0.019398      -0.010358                    -0.001157
# CANTIDAD_TECNICO         -0.011168      -0.007930                    -0.001755
# CAMPANA_HBO               0.000736            NaN                          NaN
# CAMPANA_FOX                    NaN            NaN                          NaN
# CAMPANA_ADULTO            0.000520            NaN                          NaN
# CAMPANA_EQUIPOS_ADIC     -0.023841            NaN                          NaN
# CAMPANA_ULTRAWIFI              NaN            NaN                          NaN
# CAMPANA_VOZ               0.016228            NaN                          NaN
# CAMPANA_RETENCION         0.006143            NaN                          NaN
# CAMPANA_AFECTACION_SRV         NaN            NaN                          NaN
# PART_CANT_CALL            0.006950            NaN                     0.000785
# CANT_USER                -0.005529            NaN                    -0.000751
# PROM_VEL                 -0.006349            NaN                     0.000151
# VEL_ME_8                  0.002202            NaN                    -0.000139
# VEL_10_25                -0.000145            NaN                    -0.000061
# VEL_30                   -0.000112            NaN                    -0.000319
# VEL_40_50                -0.002972            NaN                    -0.000411
# VEL_MA_60                -0.010129            NaN                    -0.000816
# CONVERGENTE              -0.008013            NaN                    -0.000762
# PROM_VEL_HOGAR           -0.006733            NaN                     0.000124
# MEDIANA_VEL              -0.009012            NaN                    -0.000055
# PROM_RENTA                0.002241            NaN                     0.000247
# PRECIO_MEGA_CLARO_1       0.005542            NaN                     0.000012
# CANTIDAD_churn           -0.000959            NaN                    -0.000474
# ANTIGUEDAD_MESES_PROM    -0.000025            NaN                    -0.000319
# ANTIGUEDAD_MESES_MED     -0.000025            NaN                    -0.000319
# AVG_TARIFA_TIGO           0.001002            NaN                     0.000665
# AVG_TIGO_MEGAS           -0.007120            NaN                    -0.000508
# PRECIO_MEGA_TIGO_1        0.002830            NaN                    -0.000332
# AVG_TARIFA_ETB           -0.010513            NaN                    -0.000072
# AVG_ETB_MEGAS            -0.008663            NaN                     0.000135
# PRECIO_MEGA_ETB_1        -0.005248            NaN                    -0.000858
# AVG_TARIFA_MOVISTAR       0.004706            NaN                     0.000696
# AVG_MOVISTAR_MEGAS       -0.012752            NaN                    -0.000304
# AVG_MOV_MEGAS            -0.000373            NaN                    -0.000885
# OPERADOR_TIGO_OOKLA       0.003966            NaN                    -0.000897
# OPERADOR_ETB_OOKLA       -0.006582            NaN                    -0.001785
# OPERADOR_MOVISTAR_OOKLA   0.001113            NaN                    -0.000941
# SUMA_OPERADORES          -0.000050            NaN                    -0.001686
# RANK1_VEL_DWLD           -0.001648            NaN                     0.000318
# OP_CLARO                  0.002118            NaN                     0.000261
# CANTIDAD                  0.003048            NaN                    -0.001058
# PENETRACION              -0.000275            NaN                    -0.000037
# OCUPACION_DW             -0.004402            NaN                    -0.000420
# OCUPACION_UP             -0.002250            NaN                    -0.001370
# ALFA                      0.000466            NaN                     0.000218
# BETA                     -0.000366            NaN                     0.000287
# MEGA                      0.001958            NaN                    -0.000045
# NIVEL_ALARMA_MALO        -0.003313            NaN                     0.000428
# NIVEL_ALARMA_BUENO       -0.007368            NaN                    -0.001090

# %%
corr_tab_V2=tidy_corr_matrix(corr_matrix_V2)

# %%
corr_tab_V2['abs_r'].describe()
# Out:
# count    581.000000
# mean       0.010636
# std        0.017587
# min        0.000012
# 25%        0.001031
# 50%        0.004402
# 75%        0.013032
# max        0.161860
# Name: abs_r, dtype: float64

# %%
corr_tab_V2[corr_tab_V2['abs_r']>=0.05].sort_values('r')
# Out:
#             variable_1         variable_2         r     abs_r
# 73      CANTIDAD_ADMIN         SIN_MOTIVO -0.161860  0.161860
# 70      CANTIDAD_ADMIN       MAL_SERVICIO -0.113602  0.113602
# 60   CANTIDAD_LLAMADAS         SIN_MOTIVO -0.112885  0.112885
# 57   CANTIDAD_LLAMADAS       MAL_SERVICIO -0.108396  0.108396
# 67      CANTIDAD_ADMIN  CAPACIDAD_DE_PAGO -0.100302  0.100302
# 95         CAMPANA_HBO       MAL_SERVICIO -0.100182  0.100182
# 34        INVOLUNTARIO         SIN_MOTIVO -0.094658  0.094658
# 291     CANTIDAD_churn         SIN_MOTIVO -0.088095  0.088095
# 48          VOLUNTARIO       SIN_CONTACTO -0.087639  0.087639
# 54   CANTIDAD_LLAMADAS  CAPACIDAD_DE_PAGO -0.068625  0.068625
# 83    CANTIDAD_TECNICO       MAL_SERVICIO -0.065645  0.065645
# 39          VOLUNTARIO        CONGELACION -0.062085  0.062085
# 72      CANTIDAD_ADMIN           NO_GUSTO -0.060359  0.060359
# 258        MEDIANA_VEL         SIN_MOTIVO -0.056589  0.056589
# 71      CANTIDAD_ADMIN        NO_UTILIZAR -0.052431  0.052431
# 42          VOLUNTARIO    CAUSAS_EXTERNAS -0.051158  0.051158
# 29        INVOLUNTARIO    CAUSAS_EXTERNAS  0.051158  0.051158
# 26        INVOLUNTARIO        CONGELACION  0.062085  0.062085
# 35        INVOLUNTARIO       SIN_CONTACTO  0.087639  0.087639
# 47          VOLUNTARIO         SIN_MOTIVO  0.094658  0.094658

# %%
# Heatmap matriz de correlaciones
# ==============================================================================
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(100, 16))
sns.heatmap(
    corr_matrix_V2,
    annot     = True,
    cbar      = False,
    annot_kws = {"size": 7},
    vmin      = -1,
    vmax      = 1,
    center    = 0,
    cmap      = sns.diverging_palette(20, 220, n=200),
    square    = True,
    ax        = ax
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation = 45,
    horizontalalignment = 'right',
)
ax.tick_params(labelsize = 10)

# %%
corr_matrix_spe = data.select_dtypes(include=['float64', 'int','int64']).corr(method='spearman')

# %%
corr_tab_spe=tidy_corr_matrix(corr_matrix_spe)
corr_tab_spe=corr_tab_spe[corr_tab_spe['variable_2']=='BAJAS_TOTAL'].drop(columns=['variable_2'])
corr_tab_spe['abs_r'].describe()
# Out:
# count    67.000000
# mean      0.072234
# std       0.109396
# min       0.000585
# 25%       0.019643
# 50%       0.034594
# 75%       0.059928
# max       0.649653
# Name: abs_r, dtype: float64

# %%
corr_tab_spe[corr_tab_spe['abs_r']>=0.059].sort_values('r')
# Out:
#              variable_1         r     abs_r
# 1287     CANTIDAD_ADMIN -0.316166  0.316166
# 1219  CANTIDAD_LLAMADAS -0.237273  0.237273
# 2579     CANTIDAD_churn -0.101448  0.101448
# 1083       INVOLUNTARIO -0.080572  0.080572
# 1419        CAMPANA_HBO -0.070883  0.070883
# 2384        MEDIANA_VEL -0.064554  0.064554
# 1151         VOLUNTARIO  0.080572  0.080572
# 702        SIN_CONTACTO  0.094661  0.094661
# 770               OTROS  0.109664  0.109664
# 566            NO_GUSTO  0.157694  0.157694
# 362         COMPETENCIA  0.182509  0.182509
# 203              VIAJES  0.194678  0.194678
# 498         NO_UTILIZAR  0.208870  0.208870
# 430        MAL_SERVICIO  0.311108  0.311108
# 135         CONGELACION  0.330994  0.330994
# 271   CAPACIDAD_DE_PAGO  0.340933  0.340933
# 634          SIN_MOTIVO  0.649653  0.649653

# %%
corr_matrix_spe_V2=corr_matrix_spe.copy()[variables_y]
corr_matrix_spe_V2=corr_matrix_spe_V2[corr_matrix_spe_V2.index.isin(variables_x)]

# %%
corr_matrix_spe_V2
# Out:
#                           CONGELACION    VIAJES  CAPACIDAD_DE_PAGO  \
# CD_BLANCOS_CAMBIOS_OTROS    -0.000438 -0.000258          -0.000452
# CHURN_TEMPRANO              -0.002953  0.015566           0.022295
# INVOLUNTARIO                 0.064678 -0.022888          -0.049117
# VOLUNTARIO                  -0.064678  0.022888           0.049117
# CANTIDAD_LLAMADAS           -0.022401 -0.046095          -0.094268
# CANTIDAD_ADMIN              -0.044905 -0.063162          -0.125125
# CANTIDAD_TECNICO             0.017820 -0.002965          -0.006994
# CAMPANA_HBO                  0.000590  0.000539           0.001232
# CAMPANA_FOX                       NaN       NaN                NaN
# CAMPANA_ADULTO               0.000417  0.000381           0.000871
# CAMPANA_EQUIPOS_ADIC         0.017409  0.013516           0.019641
# CAMPANA_ULTRAWIFI                 NaN       NaN                NaN
# CAMPANA_VOZ                 -0.008020 -0.004677          -0.012084
# CAMPANA_RETENCION            0.017561  0.009072           0.008134
# CAMPANA_AFECTACION_SRV            NaN       NaN                NaN
# PART_CANT_CALL               0.013813  0.003717          -0.003802
# CANT_USER                   -0.000594  0.004693          -0.009558
# PROM_VEL                     0.006231 -0.027269          -0.002443
# VEL_ME_8                     0.005011  0.017318          -0.005474
# VEL_10_25                   -0.003627  0.018608           0.000010
# VEL_30                       0.002893  0.018246          -0.000792
# VEL_40_50                   -0.009429  0.011165          -0.000369
# VEL_MA_60                    0.008959 -0.016978          -0.008948
# CONVERGENTE                 -0.007404  0.000589          -0.009557
# PROM_VEL_HOGAR               0.006293 -0.026977          -0.002658
# MEDIANA_VEL                 -0.002895 -0.030588          -0.007771
# PROM_RENTA                  -0.011401 -0.023100           0.006892
# PRECIO_MEGA_CLARO_1         -0.012232  0.021112           0.006689
# CANTIDAD_churn               0.002450 -0.018973          -0.038164
# ANTIGUEDAD_MESES_PROM       -0.002699 -0.011565          -0.002542
# ANTIGUEDAD_MESES_MED        -0.002699 -0.011565          -0.002542
# AVG_TARIFA_TIGO             -0.007329 -0.013599          -0.001262
# AVG_TIGO_MEGAS              -0.003357 -0.012548          -0.007424
# PRECIO_MEGA_TIGO_1           0.001373 -0.007162          -0.008280
# AVG_TARIFA_ETB              -0.002066 -0.022635          -0.001693
# AVG_ETB_MEGAS               -0.000226 -0.021342           0.001223
# PRECIO_MEGA_ETB_1           -0.000393 -0.003898          -0.010735
# AVG_TARIFA_MOVISTAR          0.002078  0.011275           0.005807
# AVG_MOVISTAR_MEGAS          -0.004026 -0.020660          -0.010604
# AVG_MOV_MEGAS               -0.001950 -0.005769          -0.007858
# OPERADOR_TIGO_OOKLA          0.008464  0.001585          -0.001399
# OPERADOR_ETB_OOKLA          -0.007098 -0.003452          -0.001227
# OPERADOR_MOVISTAR_OOKLA     -0.002099 -0.004403          -0.004011
# SUMA_OPERADORES              0.001998 -0.002478          -0.002906
# RANK1_VEL_DWLD               0.004014 -0.020183          -0.000230
# OP_CLARO                     0.006704  0.013794           0.002835
# CANTIDAD                     0.005998  0.002424           0.000907
# PENETRACION                 -0.008284 -0.002304           0.002274
# OCUPACION_DW                -0.001145  0.002951          -0.011969
# OCUPACION_UP                -0.003506 -0.003079          -0.007748
# ALFA                        -0.006678 -0.015817          -0.002764
# BETA                        -0.003651 -0.010378          -0.002376
# MEGA                        -0.005272 -0.011588          -0.001554
# NIVEL_ALARMA_MALO            0.003700 -0.004842          -0.002106
# NIVEL_ALARMA_BUENO           0.010548 -0.021024          -0.010360
#
#                           CAUSAS_EXTERNAS  COMPETENCIA  MAL_SERVICIO  \
# CD_BLANCOS_CAMBIOS_OTROS         0.003567    -0.000242     -0.000413
# CHURN_TEMPRANO                   0.007283     0.016010      0.020714
# INVOLUNTARIO                     0.051398    -0.026978     -0.043849
# VOLUNTARIO                      -0.051398     0.026978      0.043849
# CANTIDAD_LLAMADAS               -0.014547    -0.045520     -0.108119
# CANTIDAD_ADMIN                  -0.019776    -0.061153     -0.124089
# CANTIDAD_TECNICO                -0.000592    -0.005020     -0.057515
# CAMPANA_HBO                           NaN     0.000660     -0.106980
# CAMPANA_FOX                           NaN          NaN           NaN
# CAMPANA_ADULTO                        NaN     0.000467      0.000792
# CAMPANA_EQUIPOS_ADIC                  NaN    -0.000872     -0.017977
# CAMPANA_ULTRAWIFI                     NaN          NaN           NaN
# CAMPANA_VOZ                           NaN     0.000741      0.022442
# CAMPANA_RETENCION                     NaN    -0.004005     -0.003945
# CAMPANA_AFECTACION_SRV                NaN          NaN           NaN
# PART_CANT_CALL                        NaN     0.000514      0.006120
# CANT_USER                             NaN     0.004058     -0.000429
# PROM_VEL                              NaN    -0.015472     -0.029961
# VEL_ME_8                              NaN     0.015408      0.022517
# VEL_10_25                             NaN     0.010921      0.018099
# VEL_30                                NaN     0.012134      0.017714
# VEL_40_50                             NaN     0.003637      0.004245
# VEL_MA_60                             NaN    -0.007837     -0.024248
# CONVERGENTE                           NaN    -0.000874     -0.009770
# PROM_VEL_HOGAR                        NaN    -0.015429     -0.030196
# MEDIANA_VEL                           NaN    -0.019115     -0.034416
# PROM_RENTA                            NaN    -0.019302     -0.027781
# PRECIO_MEGA_CLARO_1                   NaN     0.009630      0.023589
# CANTIDAD_churn                        NaN    -0.024639     -0.041443
# ANTIGUEDAD_MESES_PROM                 NaN    -0.015603     -0.022046
# ANTIGUEDAD_MESES_MED                  NaN    -0.015603     -0.022046
# AVG_TARIFA_TIGO                       NaN    -0.012603     -0.018915
# AVG_TIGO_MEGAS                        NaN    -0.003036     -0.006763
# PRECIO_MEGA_TIGO_1                    NaN    -0.010818     -0.019330
# AVG_TARIFA_ETB                        NaN    -0.005728     -0.016549
# AVG_ETB_MEGAS                         NaN    -0.003656     -0.012402
# PRECIO_MEGA_ETB_1                     NaN    -0.006645     -0.018638
# AVG_TARIFA_MOVISTAR                   NaN     0.002435      0.004745
# AVG_MOVISTAR_MEGAS                    NaN    -0.004760     -0.015680
# AVG_MOV_MEGAS                         NaN    -0.007660     -0.016190
# OPERADOR_TIGO_OOKLA                   NaN    -0.002461     -0.001826
# OPERADOR_ETB_OOKLA                    NaN    -0.005709     -0.017251
# OPERADOR_MOVISTAR_OOKLA               NaN    -0.009589     -0.009742
# SUMA_OPERADORES                       NaN    -0.008116     -0.011202
# RANK1_VEL_DWLD                        NaN    -0.017924     -0.028336
# OP_CLARO                              NaN     0.016421      0.023685
# CANTIDAD                              NaN     0.000615      0.003412
# PENETRACION                           NaN     0.004491      0.001393
# OCUPACION_DW                          NaN     0.002183     -0.002743
# OCUPACION_UP                          NaN    -0.002278     -0.008392
# ALFA                                  NaN    -0.019266     -0.026089
# BETA                                  NaN    -0.007078     -0.011827
# MEGA                                  NaN    -0.017477     -0.022167
# NIVEL_ALARMA_MALO                     NaN    -0.001010     -0.006009
# NIVEL_ALARMA_BUENO                    NaN    -0.005580     -0.014693
#
#                           NO_UTILIZAR  NO_GUSTO  SIN_MOTIVO  SIN_CONTACTO  \
# CD_BLANCOS_CAMBIOS_OTROS    -0.000277 -0.000209   -0.000862      0.012648
# CHURN_TEMPRANO               0.015129  0.009198    0.033824      0.012277
# INVOLUNTARIO                -0.014529 -0.016474   -0.095055      0.087873
# VOLUNTARIO                   0.014529  0.016474    0.095055     -0.087873
# CANTIDAD_LLAMADAS           -0.054058 -0.049135   -0.155849     -0.025152
# CANTIDAD_ADMIN              -0.073052 -0.061930   -0.210627     -0.032852
# CANTIDAD_TECNICO            -0.002287 -0.009557   -0.010847     -0.004384
# CAMPANA_HBO                  0.000638  0.000565   -0.048027      0.000170
# CAMPANA_FOX                       NaN       NaN         NaN           NaN
# CAMPANA_ADULTO               0.000451  0.000400    0.001728      0.000120
# CAMPANA_EQUIPOS_ADIC         0.008780  0.008750    0.016654      0.008769
# CAMPANA_ULTRAWIFI                 NaN       NaN         NaN           NaN
# CAMPANA_VOZ                 -0.004195 -0.006416    0.012433     -0.006486
# CAMPANA_RETENCION            0.009971  0.000690    0.024038      0.002867
# CAMPANA_AFECTACION_SRV            NaN       NaN         NaN           NaN
# PART_CANT_CALL               0.001035  0.000572    0.002377     -0.000350
# CANT_USER                   -0.001946 -0.000635    0.001239     -0.000501
# PROM_VEL                    -0.012827 -0.005157   -0.029644     -0.000331
# VEL_ME_8                     0.004062  0.004133    0.020800      0.000277
# VEL_10_25                    0.009061  0.004175    0.021265     -0.000205
# VEL_30                       0.007471  0.003749    0.025676     -0.000459
# VEL_40_50                    0.005736 -0.000066    0.014093     -0.000497
# VEL_MA_60                   -0.011999 -0.004116   -0.019453     -0.000748
# CONVERGENTE                 -0.004747 -0.003239   -0.001548     -0.000314
# PROM_VEL_HOGAR              -0.012708 -0.005231   -0.028898     -0.000075
# MEDIANA_VEL                 -0.015688 -0.007902   -0.043781     -0.000402
# PROM_RENTA                  -0.003824 -0.005875   -0.025049     -0.000652
# PRECIO_MEGA_CLARO_1          0.013786  0.003785    0.023142     -0.000084
# CANTIDAD_churn              -0.020229 -0.016209   -0.075914     -0.000936
# ANTIGUEDAD_MESES_PROM       -0.002514 -0.004238   -0.025304     -0.000790
# ANTIGUEDAD_MESES_MED        -0.002514 -0.004238   -0.025305     -0.000790
# AVG_TARIFA_TIGO              0.001024 -0.003845   -0.025339     -0.000538
# AVG_TIGO_MEGAS              -0.013763 -0.002030   -0.024601     -0.001019
# PRECIO_MEGA_TIGO_1          -0.001246 -0.007935   -0.017138     -0.000255
# AVG_TARIFA_ETB              -0.013267 -0.001387   -0.040291     -0.000945
# AVG_ETB_MEGAS               -0.011949  0.000130   -0.035576     -0.000709
# PRECIO_MEGA_ETB_1           -0.007622 -0.006324   -0.003465     -0.000448
# AVG_TARIFA_MOVISTAR          0.012951  0.001561    0.019367      0.000927
# AVG_MOVISTAR_MEGAS          -0.017788 -0.002855   -0.039692     -0.000897
# AVG_MOV_MEGAS               -0.000951 -0.006176   -0.015520     -0.000308
# OPERADOR_TIGO_OOKLA          0.000354 -0.001714   -0.012491     -0.001547
# OPERADOR_ETB_OOKLA          -0.001814 -0.003774    0.008912      0.000021
# OPERADOR_MOVISTAR_OOKLA     -0.002312 -0.002636   -0.025300     -0.001327
# SUMA_OPERADORES             -0.001590 -0.003559   -0.017468     -0.001374
# RANK1_VEL_DWLD              -0.006764 -0.004841   -0.028725      0.000067
# OP_CLARO                     0.004317  0.005856    0.025387     -0.000281
# CANTIDAD                     0.001135  0.000841   -0.003943     -0.001166
# PENETRACION                  0.001313  0.001633    0.016093     -0.000499
# OCUPACION_DW                -0.003766 -0.003240   -0.004235     -0.000067
# OCUPACION_UP                -0.003688 -0.003083   -0.004628     -0.000533
# ALFA                        -0.004635 -0.006300   -0.032303     -0.000248
# BETA                        -0.004768 -0.003159   -0.015443     -0.000254
# MEGA                        -0.002283 -0.005143   -0.027052     -0.000142
# NIVEL_ALARMA_MALO           -0.003886 -0.000933   -0.007753      0.000243
# NIVEL_ALARMA_BUENO          -0.015987 -0.002787   -0.041653     -0.000798
#
#                              OTROS  CAMBIO_TARIFA  UNIFICACION_EMPAQUETAMIENTO
# CD_BLANCOS_CAMBIOS_OTROS -0.000145       0.009118                    -0.000027
# CHURN_TEMPRANO            0.006774       0.002897                     0.002717
# INVOLUNTARIO             -0.005686       0.020446                     0.016638
# VOLUNTARIO                0.005686      -0.020446                    -0.016638
# CANTIDAD_LLAMADAS        -0.015310      -0.006138                    -0.001812
# CANTIDAD_ADMIN           -0.016283      -0.006549                    -0.001589
# CANTIDAD_TECNICO         -0.010093      -0.004386                    -0.001397
# CAMPANA_HBO               0.000763            NaN                          NaN
# CAMPANA_FOX                    NaN            NaN                          NaN
# CAMPANA_ADULTO            0.000539            NaN                          NaN
# CAMPANA_EQUIPOS_ADIC     -0.023099            NaN                          NaN
# CAMPANA_ULTRAWIFI              NaN            NaN                          NaN
# CAMPANA_VOZ               0.021396            NaN                          NaN
# CAMPANA_RETENCION         0.010901            NaN                          NaN
# CAMPANA_AFECTACION_SRV         NaN            NaN                          NaN
# PART_CANT_CALL            0.007728            NaN                     0.000810
# CANT_USER                -0.005266            NaN                    -0.000629
# PROM_VEL                 -0.005252            NaN                     0.000140
# VEL_ME_8                  0.000850            NaN                    -0.000165
# VEL_10_25                 0.001284            NaN                    -0.000351
# VEL_30                    0.001236            NaN                    -0.000200
# VEL_40_50                -0.000894            NaN                    -0.000492
# VEL_MA_60                -0.008754            NaN                    -0.000614
# CONVERGENTE              -0.008323            NaN                    -0.000794
# PROM_VEL_HOGAR           -0.005606            NaN                     0.000103
# MEDIANA_VEL              -0.007429            NaN                     0.000067
# PROM_RENTA                0.001867            NaN                     0.000411
# PRECIO_MEGA_CLARO_1       0.007651            NaN                     0.000035
# CANTIDAD_churn           -0.001989            NaN                    -0.000975
# ANTIGUEDAD_MESES_PROM    -0.000434            NaN                    -0.000326
# ANTIGUEDAD_MESES_MED     -0.000434            NaN                    -0.000326
# AVG_TARIFA_TIGO           0.001921            NaN                     0.000570
# AVG_TIGO_MEGAS           -0.006864            NaN                    -0.000499
# PRECIO_MEGA_TIGO_1        0.002324            NaN                    -0.000504
# AVG_TARIFA_ETB           -0.010166            NaN                    -0.000043
# AVG_ETB_MEGAS            -0.008816            NaN                     0.000131
# PRECIO_MEGA_ETB_1        -0.005914            NaN                    -0.000884
# AVG_TARIFA_MOVISTAR       0.005303            NaN                     0.000664
# AVG_MOVISTAR_MEGAS       -0.012677            NaN                    -0.000304
# AVG_MOV_MEGAS             0.000756            NaN                    -0.000720
# OPERADOR_TIGO_OOKLA       0.004305            NaN                    -0.000642
# OPERADOR_ETB_OOKLA       -0.007954            NaN                    -0.001347
# OPERADOR_MOVISTAR_OOKLA   0.000710            NaN                    -0.000737
# SUMA_OPERADORES           0.000622            NaN                    -0.001062
# RANK1_VEL_DWLD           -0.001031            NaN                     0.000078
# OP_CLARO                  0.001005            NaN                     0.000375
# CANTIDAD                  0.003100            NaN                    -0.000800
# PENETRACION              -0.005859            NaN                    -0.001089
# OCUPACION_DW             -0.004037            NaN                    -0.000190
# OCUPACION_UP             -0.001759            NaN                    -0.001268
# ALFA                      0.000736            NaN                    -0.000150
# BETA                     -0.002920            NaN                     0.000210
# MEGA                      0.002256            NaN                    -0.000389
# NIVEL_ALARMA_MALO        -0.003735            NaN                     0.000495
# NIVEL_ALARMA_BUENO       -0.010128            NaN                    -0.001212

# %%
corr_tab_spe_V2=tidy_corr_matrix(corr_matrix_spe_V2)

# %%
corr_tab_spe_V2['abs_r'].describe()
# Out:
# count    581.000000
# mean       0.011680
# std        0.019705
# min        0.000010
# 25%        0.001239
# 50%        0.005020
# 75%        0.015408
# max        0.210627
# Name: abs_r, dtype: float64

# %%
corr_tab_spe_V2[corr_tab_spe_V2['abs_r']>=0.16].sort_values('r')
# Out:
#         variable_1  variable_2         r     abs_r
# 73  CANTIDAD_ADMIN  SIN_MOTIVO -0.210627  0.210627

# %% [markdown]
# ## Validar Nodos Críticos

# %%
NC_Velocidad=pd.read_csv('nodos_criticos_velocidad_promedio.csv')
NC_Tarifas=pd.read_csv('nodos_criticos_tarifas.csv')
NC_Velocidad_menor=pd.read_csv('nodos_criticos_velocidad_menor_a_promedio.csv')
NC_Volumen=pd.read_csv('nodosCriticos_volumen.csv')

# %%
NC_Volumen['NC_Vol']=NC_Volumen['COD_NODO']

# %%
NC_Velocidad_menor['NC_Vel_men']=NC_Velocidad_menor['COD_NODO']

# %%
NC_Velocidad['NC_Vel']=NC_Velocidad['COD_NODO']

# %%
NC_Tarifas=NC_Tarifas[NC_Tarifas['ET']==1][['COD_NODO']]
NC_Tarifas['NC_Tar']=NC_Tarifas['COD_NODO']

# %%
NC_com=NC_Velocidad.merge(NC_Tarifas, left_on='COD_NODO',right_on='COD_NODO',how='outer')
NC_com=NC_com.merge(NC_Velocidad_menor, left_on='COD_NODO',right_on='COD_NODO',how='outer')
NC_com=NC_com.merge(NC_Volumen, left_on='COD_NODO',right_on='COD_NODO',how='outer')

# %%
NC_com
# Out:
#      COD_NODO NC_Vel NC_Tar NC_Vel_men NC_Vol
# 0        HBP1   HBP1    NaN        NaN    NaN
# 1         8UT    8UT    NaN        NaN    NaN
# 2         OVL    OVL    NaN        NaN    NaN
# 3         GEH    GEH    GEH        NaN    NaN
# 4         URB    URB    NaN        NaN    NaN
# ...       ...    ...    ...        ...    ...
# 6943      ZS1    NaN    NaN        NaN    ZS1
# 6944      ZS4    NaN    NaN        NaN    ZS4
# 6945      ZT3    NaN    NaN        NaN    ZT3
# 6946      ZVD    NaN    NaN        NaN    ZVD
# 6947      ZVT    NaN    NaN        NaN    ZVT
#
# [6948 rows x 5 columns]

# %%
NC_com.notnull().sum()
# Out:
# COD_NODO      6948
# NC_Vel        1291
# NC_Tar        1144
# NC_Vel_men    2828
# NC_Vol        3233
# dtype: int64

# %%
#NC_com.isnull().sum()

# %%
NC_com.notnull().sum()/len(NC_com)
# Out:
# COD_NODO      1.000000
# NC_Vel        0.185809
# NC_Tar        0.164652
# NC_Vel_men    0.407024
# NC_Vol        0.465314
# dtype: float64

# %%
NC_com.drop(columns='COD_NODO').notnull().sum(axis=1).to_frame().value_counts()
# Out:
# 1    5462
# 2    1424
# 3      62
# dtype: int64

# %%
NC_com[['NC_Vel','NC_Vel_men']].dropna(how='all').notnull().sum(axis=1).to_frame().value_counts()
# Out:
# 1    3981
# 2      69
# dtype: int64

# %%
NC_com[['NC_Vel','NC_Tar']].dropna(how='all').notnull().sum(axis=1).to_frame().value_counts()
# Out:
# 1    2179
# 2     128
# dtype: int64

# %%
NC_com[['NC_Vel_men','NC_Tar']].dropna(how='all').notnull().sum(axis=1).to_frame().value_counts()
# Out:
# 1    3660
# 2     156
# dtype: int64

# %%
NC_comun=pd.DataFrame(index=NC_com.columns, columns=NC_com.columns)

# %%
for col in NC_com.columns:
    for fil in NC_com.columns:
        if col != fil:
            val=NC_com[[col,fil]].dropna(how='all').notnull().sum(axis=1).to_frame().value_counts()[2]
            NC_comun.at[col,fil]=val

# %%
NC_comun=NC_comun[NC_comun.index!='COD_NODO']

# %%
NC_comun
# Out:
#            COD_NODO NC_Vel NC_Tar NC_Vel_men NC_Vol
# NC_Vel         1291    NaN    128         69    101
# NC_Tar         1144    128    NaN        156    171
# NC_Vel_men     2828     69    156        NaN    985
# NC_Vol         3233    101    171        985    NaN
