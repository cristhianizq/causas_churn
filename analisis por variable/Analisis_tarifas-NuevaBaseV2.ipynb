# %% [markdown]
# #  Analisis Tarifas

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

# %%
data= pd.read_csv('DATA_FINAL_08.csv',sep=';', header = 0)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-326-ace999e667fe> in <module>
# ----> 1 data= pd.read_csv('DATA_FINAL_08.csv',sep=';', header = 0)
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1055     def read(self, nrows=None):
#    1056         nrows = validate_integer("nrows", nrows)
# -> 1057         index, columns, col_dict = self._engine.read(nrows)
#    1058
#    1059         if index is None:
#
# C:\ProgramData\Anaconda3\envs\ds_sqdm_claro\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2059     def read(self, nrows=None):
#    2060         try:
# -> 2061             data = self._reader.read(nrows)
#    2062         except StopIteration:
#    2063             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
len(data)

# %%
data.shape

# %%
data['COD_NODO'].nunique()

# %%
data.describe()

# %%
data['FECHA'].max()

# %% [markdown]
# # PLAN
#     1. listar Nodos
#     2. Calcular medida tarifa
#     3. Ordenar en pivot por mes
#     4. Calcular dif Ene_Mayo y dif Ene_Nov
#     5. Agrupar
#     6. Identificar causas (arbol, cluster u otros)
#
# ##  Tener en cuenta campos
# * 'CD_BLANCOS_CAMBIOS_SERVICIO'
# * analisis diferentes por INVOLUNTARIO

# %%
data.columns

# %%
data.head()

# %%
data['INVOLUNTARIO']=np.where(data['CARTERA']==0,0,np.where(data['CARTERA']=='0',0,-1))
data['VOLUNTARIO']=np.where(data['CARTERA']==0,-1,np.where(data['CARTERA']=='0',-1,0))

# %%
data[['INVOLUNTARIO','VOLUNTARIO']].value_counts().to_frame().sort_index()

# %%
def pieChart(col):
    A = col.value_counts()
    indices = A.index
    plt.pie(A, labels=indices, autopct="%0.1f %%", colors=['silver','red'])
    plt.axis("equal")
    plt.show()

# %%
pieChart(data['VOLUNTARIO'])

# %%
data['CARTERA'].unique()

# %%
data[['FECHA']].value_counts()

# %%
#data[seleccion_variables].sort_values('COD_NODO')

# %%
data_total=data.copy()

# %% [markdown]
# ### Seleccion variables para medida tarifa

# %%
seleccion_variables=['COD_NODO','FECHA','INVOLUNTARIO','CD_BLANCOS_CAMBIOS_SERVICIO','AVG_TARIFA_TIGO','AVG_TARIFA_ETB','AVG_TARIFA_MOVISTAR','PROM_RENTA']
# no hay precio mega Movistart

# %%
data[seleccion_variables].isnull().sum()

# %%
data[seleccion_variables].isnull().sum()/len(data)

# %%
data[seleccion_variables].describe()

# %%
#alfa=com/nuestro

# %%
data_medida=data[seleccion_variables].copy()

# %%
variables_tarifa=['AVG_TARIFA_TIGO','AVG_TARIFA_ETB','AVG_TARIFA_MOVISTAR']

# %%
data_medida['comp_tarifa']=data_medida[variables_tarifa].min(axis=1)

# %%
data_medida['operador_menor_tarifa']=np.where(data_medida['comp_tarifa']==data_medida['AVG_TARIFA_TIGO'],'AVG_TARIFA_TIGO',
                                              np.where(data_medida['comp_tarifa']==data_medida['AVG_TARIFA_ETB'],'AVG_TARIFA_ETB',
                                                      np.where(data_medida['comp_tarifa']==data_medida['AVG_TARIFA_MOVISTAR'],'AVG_TARIFA_MOVISTAR','NINGUNO'
                                             )))

# %%
data_medida['ALFA_tarifa']=np.where(data_medida['operador_menor_tarifa']=='NINGUNO',np.nan,data_medida['comp_tarifa']/data_medida['PROM_RENTA'])

# %%
data_medida

# %%
data_medida['FECHA'].max()

# %%
resumen_medida=pd.pivot_table(data_medida[['FECHA','COD_NODO','ALFA_tarifa']], columns='FECHA', index='COD_NODO',aggfunc=np.mean)
resumen_medida.columns = resumen_medida.columns.droplevel()
resumen_medida

# %%
data_medida[data_medida['COD_NODO']=='01S'].sort_values('FECHA')

# %%
resumen_medida.isnull().sum()

# %%
resumen_medida.isnull().sum()/len(resumen_medida)

# %%
sns.violinplot(data=resumen_medida)

# %%
resumen_medida.median().to_frame().plot()

# %%
resumen_medida['ene_oct']=resumen_medida[10]-resumen_medida[1]
resumen_medida['ene_may']=resumen_medida[5]-resumen_medida[1]

# %%
resumen_medida.describe()
# Out:
# FECHA            1            2            3            4            5  \
# count  6741.000000  6698.000000  6893.000000  7064.000000  6939.000000
# mean      0.986862     0.986459     0.986282     0.985155     0.989091
# std       0.222228     0.219783     0.218010     0.216290     0.218906
# min       0.424251     0.427115     0.443353     0.459624     0.432857
# 25%       0.824723     0.824866     0.828721     0.824852     0.829139
# 50%       0.976559     0.974808     0.974402     0.976436     0.977812
# 75%       1.127861     1.122591     1.120084     1.120176     1.123003
# max       2.567901     2.282624     2.918921     2.256057     2.353665
#
# FECHA            6            7            8            9           10  \
# count  7130.000000  7362.000000  7317.000000  7633.000000  7521.000000
# mean      0.985250     0.981769     1.007998     0.889634     0.896673
# std       0.217622     0.211938     0.214597     0.172056     0.169832
# min       0.421675     0.423495     0.432636     0.367525     0.346936
# 25%       0.826536     0.830247     0.854087     0.782884     0.790782
# 50%       0.973474     0.973728     0.998418     0.880032     0.887263
# 75%       1.117394     1.111162     1.135050     0.991742     0.997337
# max       2.362262     2.378556     2.472470     1.943738     1.918936
#
# FECHA      ene_oct      ene_may
# count  5716.000000  5517.000000
# mean     -0.096479    -0.007082
# std       0.170847     0.177239
# min      -0.964745    -1.020891
# 25%      -0.199995    -0.061030
# 50%      -0.111612     0.000709
# 75%       0.015904     0.047504
# max       0.371453     0.670422

# %%
sns.violinplot(data=resumen_medida[['ene_oct','ene_may']])
# Out:
# <AxesSubplot:xlabel='FECHA'>

# %%
resumen_medida['ene_oct'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
resumen_medida['ene_may'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
ax = resumen_medida[['ene_oct','ene_may']].plot.hist(bins=100, alpha=0.5)

# %%
resumen_medida
# Out:
# FECHA            1         2         3         4         5         6  \
# COD_NODO
# 01S            NaN       NaN  0.875348  0.871263  1.209064  0.863952
# 02S       1.274914  0.907934  1.277684  1.258177  1.259581  1.270295
# 0AL            NaN       NaN  0.738222       NaN  0.728679  0.539047
# 0AO       0.810964       NaN  0.988197  1.077074       NaN       NaN
# 0AR       1.284109  1.216581  1.298053  1.183848  1.104240  1.320534
# ...            ...       ...       ...       ...       ...       ...
# ZUL       1.063994       NaN  1.671811  1.072029  1.091996  1.088498
# ZVD       0.986515  0.960976  0.974316  0.979039  0.931441  0.957367
# ZVG       1.172341  1.176593  1.132425  1.066752  1.174378  1.166202
# ZVS       0.959760  1.121800  1.156596  1.157604  1.087080  1.102153
# ZVT            NaN  0.843362  0.623238  0.726892  0.622475       NaN
#
# FECHA            7         8         9        10   ene_oct   ene_may
# COD_NODO
# 01S       0.860241       NaN       NaN  1.035875       NaN       NaN
# 02S       1.254361  0.909536  1.103387  0.957562 -0.317352 -0.015333
# 0AL       0.760157       NaN       NaN  0.474946       NaN       NaN
# 0AO            NaN       NaN  0.680075       NaN       NaN       NaN
# 0AR       1.172261  1.336661  1.033125  1.029064 -0.255045 -0.179869
# ...            ...       ...       ...       ...       ...       ...
# ZUL       1.090459  1.112140  1.159577  1.121575  0.057581  0.028003
# ZVD       0.953681  0.961424  0.894125  0.844062 -0.142453 -0.055074
# ZVG       1.072115  1.195050  1.040057  1.041562 -0.130779  0.002037
# ZVS       1.101199  1.179469  1.024236  0.952015 -0.007745  0.127320
# ZVT       0.623224  0.634243  0.755914  0.542212       NaN       NaN
#
# [9704 rows x 12 columns]

# %%
resumen_medida.isnull().sum()
# Out:
# FECHA
# 1          2963
# 2          3006
# 3          2811
# 4          2640
# 5          2765
# 6          2574
# 7          2342
# 8          2387
# 9          2071
# 10         2183
# ene_oct    3988
# ene_may    4187
# dtype: int64

# %%
resumen_medida.isnull().sum()/len(resumen_medida)
# Out:
# FECHA
# 1          0.305338
# 2          0.309769
# 3          0.289674
# 4          0.272053
# 5          0.284934
# 6          0.265251
# 7          0.241344
# 8          0.245981
# 9          0.213417
# 10         0.224959
# ene_oct    0.410965
# ene_may    0.431472
# dtype: float64

# %%
resumen_medida['bin_alfa']=pd.cut((resumen_medida['ene_oct']),bins=5,right=True)

# %%
resumen_medida['bin_alfa'].value_counts().to_frame().sort_index()
# Out:
#                   bin_alfa
# (-0.966, -0.698]         5
# (-0.698, -0.43]        119
# (-0.43, -0.163]       1772
# (-0.163, 0.104]       2823
# (0.104, 0.371]         997

# %%
len(resumen_medida)
# Out:
# 9704

# %%
resumen_medida['ene_oct'].quantile(0.10)
# Out:
# -0.3056786529375847

# %%
(resumen_medida['ene_oct']<=-0.25).sum()
# Out:
# 988

# %%
(resumen_medida['ene_oct']<=-0.25).sum()/len(resumen_medida)
# Out:
# 0.10181368507831821

# %%
len(resumen_medida)
# Out:
# 9704

# %%
corte=resumen_medida['ene_oct'].quantile(0.20)
corte
# Out:
# -0.23248164336784183

# %%
len(resumen_medida[resumen_medida['ene_oct']<=corte])
# Out:
# 1144

# %% [markdown]
# ###  Segunda parte

# %%
seleccionVariables=['CONGELACION','VIAJES','CAPACIDAD_DE_PAGO','CAUSAS_EXTERNAS','COMPETENCIA','MAL_SERVICIO','NO_UTILIZAR',
                    'NO_GUSTO','SIN_MOTIVO','SIN_CONTACTO','TRASLADOS','OTROS','CAMBIO_DE_SERVICIO','CAMBIO_TARIFA','EMPAQUETAMIENTO',
                    'CESION_DE_CONTRATO','UNIFICACION_EMPAQUETAMIENTO']

# Sin 'CD_BLANCOS_CAMBIOS_OTROS'

# %% [markdown]
# ### Pregunta
# * tome la diferencia de enero a oct.  Debo tomar el cambio de tendencia?

# %%
data_causal=data.merge(resumen_medida[['ene_oct']], left_on='COD_NODO', right_index=True, how='left')

# %%
data_causal['ET']=np.where(data_causal['ene_oct']<=corte,1,0)

# %%
data_causal['ET'].value_counts()
# Out:
# 0    3346566
# 1     401826
# Name: ET, dtype: int64

# %%
data_causal['ET'].value_counts()/len(data_causal)
# Out:
# 0    0.8928
# 1    0.1072
# Name: ET, dtype: float64

# %% [markdown]
# ## Fase 2
# * Caracterizar Casos Graves
# * Arboles

# %%
data_causal
# Out:
#            CUENTA COD_SERVICIO Velocidad Internet COD_NODO ESTRATO CARTERA  \
# 0        88384766          NB2         @       50      ZG2       3       0
# 1        92228220          DV3       NaN       60     HBP1       3       0
# 2        48074413          5BA       NaN        5    PPA4D       3       0
# 3         2139171          SUD         @       10      9BZ       2       0
# 4        14885225          D3V         @      160      SNJ       4       0
# ...           ...          ...       ...      ...      ...     ...     ...
# 3748387  90354179          PH5         @        5      1GV       2       0
# 3748388   8087598          CMB         @      100      CVB       4       0
# 3748389  71164933          R30         @       30      BTC       2       0
# 3748390  71189674          5BA         @        5      P04       4       0
# 3748391  42135323          MT3         @        8     4VU1       2       0
#
#          CONGELACION  VIAJES  CAPACIDAD_DE_PAGO  ...      MEGA  \
# 0                  0       0                  0  ...  0.714482
# 1                  0       0                  0  ...  0.414081
# 2                  0       0                  0  ...  2.877093
# 3                  0       0                  0  ...  1.108223
# 4                  0       0                  0  ...  1.006936
# ...              ...     ...                ...  ...       ...
# 3748387            0       0                  0  ...  1.686854
# 3748388            0       0                  0  ...  2.063867
# 3748389            0       0                  0  ...  0.441224
# 3748390            0       0                  0  ...  1.873057
# 3748391            0       0                  0  ...       NaN
#
#          NIVEL_ALARMA_MALO  NIVEL_ALARMA_BUENO             DIVISION  \
# 0                      0.0                 2.0  REGION NOROCCIDENTE
# 1                      0.0                 0.0        REGION CENTRO
# 2                      0.0                 0.0         REGION COSTA
# 3                      0.0                 3.0        REGION CENTRO
# 4                      0.0                 0.0       REGION ORIENTE
# ...                    ...                 ...                  ...
# 3748387                0.0                 2.0  REGION NOROCCIDENTE
# 3748388                0.0                 2.0       REGION ORIENTE
# 3748389                0.0                 0.0        REGION CENTRO
# 3748390                0.0                 1.0       REGION ORIENTE
# 3748391                0.0                 1.0        REGION CENTRO
#
#                      AREA                       ZONA         CIUDAD  \
# 0                MEDELLIN               MEDELLIN SUR       MEDELLIN
# 1        BOGOTA OCCIDENTE           SABANA OCCIDENTE         MADRID
# 2             COSTA NORTE                      CESAR     VALLEDUPAR
# 3              BOGOTA SUR                       BOSA         BOGOTA
# 4                  SANBOY  BUCARAMANGA-METROPOLITANA    BUCARAMANGA
# ...                   ...                        ...            ...
# 3748387          MEDELLIN             MEDELLIN NORTE          BELLO
# 3748388            SANBOY  BUCARAMANGA-METROPOLITANA  FLORIDABLANCA
# 3748389        BOGOTA SUR                       BOSA         BOGOTA
# 3748390            SANBOY  BUCARAMANGA-METROPOLITANA    BUCARAMANGA
# 3748391        BOGOTA SUR                   MADELENA         BOGOTA
#
#                      DISTRITO   ene_oct  ET
# 0        MEDELLIN SURORIENTAL       NaN   0
# 1                      MADRID       NaN   0
# 2            CESAR DISTRITO 1       NaN   0
# 3                        ROMA -0.139428   0
# 4              DISTRITO BGA 1       NaN   0
# ...                       ...       ...  ..
# 3748387           BELLO NORTE       NaN   0
# 3748388    DISTRITO FLORIDA 1       NaN   0
# 3748389                  ROMA  0.160395   0
# 3748390        DISTRITO BGA 3 -0.078399   0
# 3748391            EL ENSUE?O       NaN   0
#
# [3748392 rows x 89 columns]

# %%
data_causal[seleccionVariables].describe()
# Out:
#         CONGELACION        VIAJES  CAPACIDAD_DE_PAGO  CAUSAS_EXTERNAS  \
# count  3.748392e+06  3.748392e+06       3.748392e+06     3.748392e+06
# mean  -1.504672e-02 -5.203565e-03      -1.582225e-02    -4.220476e-04
# std    1.241560e-01  7.226600e-02       1.257225e-01     2.069474e-02
# min   -9.000000e+00 -4.000000e+00      -4.000000e+00    -4.000000e+00
# 25%    0.000000e+00  0.000000e+00       0.000000e+00     0.000000e+00
# 50%    0.000000e+00  0.000000e+00       0.000000e+00     0.000000e+00
# 75%    0.000000e+00  0.000000e+00       0.000000e+00     0.000000e+00
# max    1.000000e+00  0.000000e+00       0.000000e+00     0.000000e+00
#
#         COMPETENCIA  MAL_SERVICIO   NO_UTILIZAR      NO_GUSTO    SIN_MOTIVO  \
# count  3.748392e+06  3.748392e+06  3.748392e+06  3.748392e+06  3.748392e+06
# mean  -4.578763e-03 -1.319766e-02 -5.989768e-03 -3.430804e-03 -5.514871e-02
# std    6.785440e-02  1.147941e-01  7.759589e-02  5.899487e-02  2.299634e-01
# min   -4.000000e+00 -4.000000e+00 -4.000000e+00 -4.000000e+00 -6.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#        SIN_CONTACTO  TRASLADOS         OTROS  CAMBIO_DE_SERVICIO  \
# count  3.748392e+06  3748392.0  3.748392e+06           3748392.0
# mean  -1.234396e-03        0.0 -1.677253e-03                 0.0
# std    3.527904e-02        0.0  4.208976e-02                 0.0
# min   -4.000000e+00        0.0 -3.000000e+00                 0.0
# 25%    0.000000e+00        0.0  0.000000e+00                 0.0
# 50%    0.000000e+00        0.0  0.000000e+00                 0.0
# 75%    0.000000e+00        0.0  0.000000e+00                 0.0
# max    0.000000e+00        0.0  0.000000e+00                 0.0
#
#        CAMBIO_TARIFA  EMPAQUETAMIENTO  CESION_DE_CONTRATO  \
# count   3.748392e+06        3748392.0           3748392.0
# mean   -7.176411e-05              0.0                 0.0
# std     9.137688e-03              0.0                 0.0
# min    -3.000000e+00              0.0                 0.0
# 25%     0.000000e+00              0.0                 0.0
# 50%     0.000000e+00              0.0                 0.0
# 75%     0.000000e+00              0.0                 0.0
# max     0.000000e+00              0.0                 0.0
#
#        UNIFICACION_EMPAQUETAMIENTO
# count                 3.748392e+06
# mean                 -5.975896e-05
# std                   7.900836e-03
# min                  -2.000000e+00
# 25%                   0.000000e+00
# 50%                   0.000000e+00
# 75%                   0.000000e+00
# max                   0.000000e+00

# %%
data_causal[seleccionVariables]=data_causal[seleccionVariables]*-1

# %%
data_causal['BAJAS TOTAL']=data_causal[seleccionVariables].sum(axis=1)

# %%
#data_causal['ET','BAJAS TOTAL']
sns.violinplot(data=data_causal, x="ET", y="BAJAS TOTAL")
# Out:
# <AxesSubplot:xlabel='ET', ylabel='BAJAS TOTAL'>

# %%
data_causal[data_causal['ET']==1][seleccionVariables].sum().to_frame().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data_causal[data_causal['ET']==0][seleccionVariables].sum().to_frame().plot.bar()
# Out:
# <AxesSubplot:>

# %%
resumen_causa=data_causal[seleccionVariables].sum().to_frame()
resumen_causa=resumen_causa.merge(data_causal[data_causal['ET']==1][seleccionVariables].sum().to_frame(), left_index=True,right_index=True, how='left')
resumen_causa=resumen_causa.merge(data_causal[data_causal['ET']==0][seleccionVariables].sum().to_frame(), left_index=True,right_index=True, how='left')
resumen_causa.columns=['total','critico','normal']
resumen_causa
# Out:
#                               total  critico  normal
# CONGELACION                   56401     3853   52548
# VIAJES                        19505     1897   17608
# CAPACIDAD_DE_PAGO             59308     6529   52779
# CAUSAS_EXTERNAS                1582        0    1582
# COMPETENCIA                   17163     1852   15311
# MAL_SERVICIO                  49470     5232   44238
# NO_UTILIZAR                   22452     2271   20181
# NO_GUSTO                      12860     1391   11469
# SIN_MOTIVO                   206719    22288  184431
# SIN_CONTACTO                   4627        0    4627
# TRASLADOS                         0        0       0
# OTROS                          6287      565    5722
# CAMBIO_DE_SERVICIO                0        0       0
# CAMBIO_TARIFA                   269        0     269
# EMPAQUETAMIENTO                   0        0       0
# CESION_DE_CONTRATO                0        0       0
# UNIFICACION_EMPAQUETAMIENTO     224        3     221

# %%
x = resumen_causa.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
resumen_causa_nor = pd.DataFrame(x_scaled)
resumen_causa_nor.index=resumen_causa.index
resumen_causa_nor.columns=resumen_causa.columns
resumen_causa_nor=resumen_causa_nor.sort_values('total', ascending=True)
resumen_causa_nor
# Out:
#                                 total   critico    normal
# EMPAQUETAMIENTO              0.000000  0.000000  0.000000
# CESION_DE_CONTRATO           0.000000  0.000000  0.000000
# TRASLADOS                    0.000000  0.000000  0.000000
# CAMBIO_DE_SERVICIO           0.000000  0.000000  0.000000
# UNIFICACION_EMPAQUETAMIENTO  0.001084  0.000135  0.001198
# CAMBIO_TARIFA                0.001301  0.000000  0.001459
# CAUSAS_EXTERNAS              0.007653  0.000000  0.008578
# SIN_CONTACTO                 0.022383  0.000000  0.025088
# OTROS                        0.030413  0.025350  0.031025
# NO_GUSTO                     0.062210  0.062410  0.062186
# COMPETENCIA                  0.083026  0.083094  0.083017
# VIAJES                       0.094355  0.085113  0.095472
# NO_UTILIZAR                  0.108611  0.101893  0.109423
# MAL_SERVICIO                 0.239310  0.234745  0.239862
# CONGELACION                  0.272839  0.172873  0.284920
# CAPACIDAD_DE_PAGO            0.286902  0.292938  0.286172
# SIN_MOTIVO                   1.000000  1.000000  1.000000

# %%
f = plt.figure()
resumen_causa_nor[['critico','normal']].plot.barh();
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
resumen_causa_nor['dif']=resumen_causa_nor['critico']-resumen_causa_nor['normal']

# %%
resumen_causa_nor=resumen_causa_nor.sort_values('dif', ascending=True)
resumen_causa_nor
# Out:
#                                 total   critico    normal       dif
# CONGELACION                  0.272839  0.172873  0.284920 -0.112046
# SIN_CONTACTO                 0.022383  0.000000  0.025088 -0.025088
# VIAJES                       0.094355  0.085113  0.095472 -0.010359
# CAUSAS_EXTERNAS              0.007653  0.000000  0.008578 -0.008578
# NO_UTILIZAR                  0.108611  0.101893  0.109423 -0.007530
# OTROS                        0.030413  0.025350  0.031025 -0.005675
# MAL_SERVICIO                 0.239310  0.234745  0.239862 -0.005117
# CAMBIO_TARIFA                0.001301  0.000000  0.001459 -0.001459
# UNIFICACION_EMPAQUETAMIENTO  0.001084  0.000135  0.001198 -0.001064
# EMPAQUETAMIENTO              0.000000  0.000000  0.000000  0.000000
# CAMBIO_DE_SERVICIO           0.000000  0.000000  0.000000  0.000000
# TRASLADOS                    0.000000  0.000000  0.000000  0.000000
# CESION_DE_CONTRATO           0.000000  0.000000  0.000000  0.000000
# SIN_MOTIVO                   1.000000  1.000000  1.000000  0.000000
# COMPETENCIA                  0.083026  0.083094  0.083017  0.000077
# NO_GUSTO                     0.062210  0.062410  0.062186  0.000224
# CAPACIDAD_DE_PAGO            0.286902  0.292938  0.286172  0.006766

# %%
# Diferencia entre críticos y normales
resumen_causa_nor[['dif']].plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## ARBOL

# %%
def visualizarArbol(model_fit,depth):
    fig, ax = plt.subplots(figsize=(depth*10,10))
    print(f"Profundidad del árbol: {tree_model.get_depth()}")
    print(f"Número de nodos terminales: {tree_model.get_n_leaves()}")
    plot = plot_tree(
                decision_tree = tree_model,
                feature_names = seleccionVariables,
                class_names   = ['normal','critico'],
                filled        = True,
                impurity      = False,
                fontsize      = 10,
                precision     = 3,
                ax            = ax
           )

# %%
tree_model = DecisionTreeClassifier(random_state=0, max_depth=5,min_samples_leaf=500, class_weight='balanced')
model_fit = tree_model.fit(X = data_causal[seleccionVariables], y = data_causal["ET"])
visualizarArbol(model_fit,3)
# Out:
# Profundidad del árbol: 5
# Número de nodos terminales: 7

# %% [markdown]
# ### Próximos pasos
# * diferenciar entre voluntarios e involuntarios
# * quitar variable blanco
# * validar cambio tendencia ene-may

# %% [markdown]
# ### Descripción Críticos

# %%
maestro_nodos=data_causal[['COD_NODO','DIVISION', 'AREA', 'ZONA', 'CIUDAD', 'DISTRITO']].dropna().drop_duplicates()

# %%
len(maestro_nodos)
# Out:
# 13687

# %%
maestro_nodos['COD_NODO'].value_counts()
# Out:
# 3A3012    1
# P1O       1
# SES       1
# PCM3B     1
# F4M1      1
#          ..
# UAZ       1
# VL11      1
# CPQ       1
# MTZ       1
# IG7       1
# Name: COD_NODO, Length: 13687, dtype: int64

# %%
maestro_nodos
# Out:
#         COD_NODO             DIVISION              AREA  \
# 0            ZG2  REGION NOROCCIDENTE          MEDELLIN
# 1           HBP1        REGION CENTRO  BOGOTA OCCIDENTE
# 2          PPA4D         REGION COSTA       COSTA NORTE
# 3            9BZ        REGION CENTRO        BOGOTA SUR
# 4            SNJ       REGION ORIENTE            SANBOY
# ...          ...                  ...               ...
# 3584383     LFD1       REGION ORIENTE            SANBOY
# 3587577   14B13B        REGION CENTRO        BOGOTA SUR
# 3641379     LBS1     REGION OCCIDENTE              CALI
# 3709544    QS23B        REGION CENTRO    BOGOTA ORIENTE
# 3724286    ORE3D        REGION CENTRO      BOGOTA NORTE
#
#                               ZONA       CIUDAD               DISTRITO
# 0                     MEDELLIN SUR     MEDELLIN   MEDELLIN SURORIENTAL
# 1                 SABANA OCCIDENTE       MADRID                 MADRID
# 2                            CESAR   VALLEDUPAR       CESAR DISTRITO 1
# 3                             BOSA       BOGOTA                   ROMA
# 4        BUCARAMANGA-METROPOLITANA  BUCARAMANGA         DISTRITO BGA 1
# ...                            ...          ...                    ...
# 3584383                     BOYACA        TUNJA              TUNJA SUR
# 3587577                    ALSACIA       BOGOTA               CASTILLA
# 3641379                 CALI NORTE         CALI  CALI NORTE DISTRITO 2
# 3709544                   RESTREPO       BOGOTA                  OLAYA
# 3724286               SABANA NORTE         COTA                 CAJICA
#
# [13687 rows x 6 columns]

# %%
maestro_nodos[maestro_nodos['COD_NODO']=='LC33B']
# Out:
#      COD_NODO       DIVISION          AREA          ZONA     CIUDAD   DISTRITO
# 1592    LC33B  REGION CENTRO  BOGOTA NORTE  SABANA NORTE  LA CALERA  TOCANCIPA

# %%
resumen_medida
# Out:
# FECHA            1         2         3         4         5         6  \
# COD_NODO
# 01S            NaN       NaN  0.875348  0.871263  1.209064  0.863952
# 02S       1.274914  0.907934  1.277684  1.258177  1.259581  1.270295
# 0AL            NaN       NaN  0.738222       NaN  0.728679  0.539047
# 0AO       0.810964       NaN  0.988197  1.077074       NaN       NaN
# 0AR       1.284109  1.216581  1.298053  1.183848  1.104240  1.320534
# ...            ...       ...       ...       ...       ...       ...
# ZUL       1.063994       NaN  1.671811  1.072029  1.091996  1.088498
# ZVD       0.986515  0.960976  0.974316  0.979039  0.931441  0.957367
# ZVG       1.172341  1.176593  1.132425  1.066752  1.174378  1.166202
# ZVS       0.959760  1.121800  1.156596  1.157604  1.087080  1.102153
# ZVT            NaN  0.843362  0.623238  0.726892  0.622475       NaN
#
# FECHA            7         8         9        10   ene_oct   ene_may  \
# COD_NODO
# 01S       0.860241       NaN       NaN  1.035875       NaN       NaN
# 02S       1.254361  0.909536  1.103387  0.957562 -0.317352 -0.015333
# 0AL       0.760157       NaN       NaN  0.474946       NaN       NaN
# 0AO            NaN       NaN  0.680075       NaN       NaN       NaN
# 0AR       1.172261  1.336661  1.033125  1.029064 -0.255045 -0.179869
# ...            ...       ...       ...       ...       ...       ...
# ZUL       1.090459  1.112140  1.159577  1.121575  0.057581  0.028003
# ZVD       0.953681  0.961424  0.894125  0.844062 -0.142453 -0.055074
# ZVG       1.072115  1.195050  1.040057  1.041562 -0.130779  0.002037
# ZVS       1.101199  1.179469  1.024236  0.952015 -0.007745  0.127320
# ZVT       0.623224  0.634243  0.755914  0.542212       NaN       NaN
#
# FECHA            bin_alfa
# COD_NODO
# 01S                   NaN
# 02S       (-0.43, -0.163]
# 0AL                   NaN
# 0AO                   NaN
# 0AR       (-0.43, -0.163]
# ...                   ...
# ZUL       (-0.163, 0.104]
# ZVD       (-0.163, 0.104]
# ZVG       (-0.163, 0.104]
# ZVS       (-0.163, 0.104]
# ZVT                   NaN
#
# [9704 rows x 13 columns]

# %%
sel_var=['DIVISION', 'AREA', 'ZONA', 'CIUDAD', 'DISTRITO']

# %%
resumen_medida_desc=resumen_medida.merge(maestro_nodos,left_index=True,right_on='COD_NODO',how='left')

# %%
resumen_medida_desc['ET']=np.where(resumen_medida_desc['ene_oct']<=corte,1,0)

# %%
resumen_medida_desc
# Out:
#                  1         2         3         4         5         6  \
# 10702.0        NaN       NaN  0.875348  0.871263  1.209064  0.863952
# 22605.0   1.274914  0.907934  1.277684  1.258177  1.259581  1.270295
# 11801.0        NaN       NaN  0.738222       NaN  0.728679  0.539047
# 289054.0  0.810964       NaN  0.988197  1.077074       NaN       NaN
# 150304.0  1.284109  1.216581  1.298053  1.183848  1.104240  1.320534
# ...            ...       ...       ...       ...       ...       ...
# 369575.0  1.063994       NaN  1.671811  1.072029  1.091996  1.088498
# 188327.0  0.986515  0.960976  0.974316  0.979039  0.931441  0.957367
# 389378.0  1.172341  1.176593  1.132425  1.066752  1.174378  1.166202
# 216450.0  0.959760  1.121800  1.156596  1.157604  1.087080  1.102153
# 294709.0       NaN  0.843362  0.623238  0.726892  0.622475       NaN
#
#                  7         8         9        10   ene_oct   ene_may  \
# 10702.0   0.860241       NaN       NaN  1.035875       NaN       NaN
# 22605.0   1.254361  0.909536  1.103387  0.957562 -0.317352 -0.015333
# 11801.0   0.760157       NaN       NaN  0.474946       NaN       NaN
# 289054.0       NaN       NaN  0.680075       NaN       NaN       NaN
# 150304.0  1.172261  1.336661  1.033125  1.029064 -0.255045 -0.179869
# ...            ...       ...       ...       ...       ...       ...
# 369575.0  1.090459  1.112140  1.159577  1.121575  0.057581  0.028003
# 188327.0  0.953681  0.961424  0.894125  0.844062 -0.142453 -0.055074
# 389378.0  1.072115  1.195050  1.040057  1.041562 -0.130779  0.002037
# 216450.0  1.101199  1.179469  1.024236  0.952015 -0.007745  0.127320
# 294709.0  0.623224  0.634243  0.755914  0.542212       NaN       NaN
#
#                  bin_alfa COD_NODO             DIVISION          AREA  \
# 10702.0               NaN      01S        REGION CENTRO  BOGOTA NORTE
# 22605.0   (-0.43, -0.163]      02S        REGION CENTRO  BOGOTA NORTE
# 11801.0               NaN      0AL         REGION COSTA     COSTA SUR
# 289054.0              NaN      0AO       REGION ORIENTE        SANBOY
# 150304.0  (-0.43, -0.163]      0AR  REGION NOROCCIDENTE      MEDELLIN
# ...                   ...      ...                  ...           ...
# 369575.0  (-0.163, 0.104]      ZUL  REGION NOROCCIDENTE  EJE CAFETERO
# 188327.0  (-0.163, 0.104]      ZVD     REGION OCCIDENTE          CALI
# 389378.0  (-0.163, 0.104]      ZVG     REGION OCCIDENTE          CALI
# 216450.0  (-0.163, 0.104]      ZVS     REGION OCCIDENTE          CALI
# 294709.0              NaN      ZVT        REGION CENTRO    BOGOTA SUR
#
#                         ZONA        CIUDAD                   DISTRITO  ET
# 10702.0                 SUBA        BOGOTA                    GAITANA   0
# 22605.0                 SUBA        BOGOTA                    GAITANA   1
# 11801.0       BARRANQUILLA 2  BARRANQUILLA  BARRANQUILLA 2 DISTRITO 2   0
# 289054.0  NORTE DE SANTANDER        CUCUTA          DISTRITO CUCUTA 2   0
# 150304.0      MEDELLIN NORTE      MEDELLIN       MEDELLIN NORORIENTAL   1
# ...                      ...           ...                        ...  ..
# 369575.0              CALDAS     MANIZALES          MANIZALES CALDAS6   0
# 188327.0          CALI NORTE          CALI      CALI NORTE DISTRITO 2   0
# 389378.0            CALI SUR          CALI        CALI SUR DISTRITO 2   0
# 216450.0            CALI SUR          CALI        CALI SUR DISTRITO 2   0
# 294709.0             ALSACIA        BOGOTA                   MARSELLA   0
#
# [9704 rows x 20 columns]

# %%
resumen_medida_desc[resumen_medida_desc['ET']==1][['DIVISION']].value_counts().to_frame().plot.bar()
# Out:
# <AxesSubplot:xlabel='DIVISION'>

# %%
resumen_medida_desc[resumen_medida_desc['ET']==1][['ZONA']].value_counts().to_frame().plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='ZONA'>

# %%
resumen_medida_desc[resumen_medida_desc['ET']==1][['CIUDAD']].value_counts().to_frame().plot.bar(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='CIUDAD'>

# %%
resumen_medida_desc_rel=pd.crosstab(index=resumen_medida_desc['CIUDAD'],
            columns=resumen_medida_desc['ET'], margins=True, normalize='index')

# %%
resumen_medida_desc_rel[1].sort_values(ascending=False).plot.bar(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='CIUDAD'>

# %%
resumen_medida_desc_rel=pd.crosstab(index=resumen_medida_desc['ZONA'],
            columns=resumen_medida_desc['ET'], margins=True, normalize='index')

# %%
resumen_medida_desc_rel[1].sort_values(ascending=False).plot.bar(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='CIUDAD'>

# %%
resumen_medida_desc_rel[1].sort_values(ascending=False)
# Out:
# CIUDAD
# MEDELLIN         0.427851
# MANIZALES        0.360825
# TULUA            0.268657
# ARMENIA          0.156522
# PASTO            0.156069
# IBAGUE           0.124481
# VILLAVICENCIO    0.118227
# All              0.117987
# PEREIRA          0.104972
# TUNJA            0.101852
# PALMIRA          0.089552
# CALI             0.086449
# CUCUTA           0.083067
# BUCARAMANGA      0.080128
# BOGOTA           0.069002
# BARRANQUILLA     0.050485
# CARTAGENA        0.047619
# CHIA             0.043478
# SOACHA           0.000000
# Name: 1, dtype: float64

# %%
pd.crosstab(index=resumen_medida_desc['CIUDAD'],
            columns=resumen_medida_desc['ET'], margins=True).sort_values(1,ascending=False)
# Out:
# ET                0     1   All
# CIUDAD
# All            8552  1144  9696
# MEDELLIN        567   424   991
# BOGOTA         4385   325  4710
# CALI            782    74   856
# MANIZALES       124    70   194
# IBAGUE          211    30   241
# PASTO           146    27   173
# CUCUTA          287    26   313
# BARRANQUILLA    489    26   515
# BUCARAMANGA     287    25   312
# VILLAVICENCIO   179    24   203
# PEREIRA         162    19   181
# TULUA            49    18    67
# ARMENIA          97    18   115
# PALMIRA         122    12   134
# CARTAGENA       220    11   231
# TUNJA            97    11   108
# CHIA             88     4    92
# SOACHA          260     0   260

# %%
resumen_medida_desc.to_csv('nodos_criticos_tarifas.csv',index=False)

# %% [markdown]
# ### Voluntario

# %%
data=data[data['INVOLUNTARIO']==0]

# %%
seleccion_variables=['COD_NODO','FECHA','INVOLUNTARIO','CD_BLANCOS_CAMBIOS_SERVICIO','AVG_TARIFA_TIGO','AVG_TARIFA_ETB','AVG_TARIFA_MOVISTAR','PROM_RENTA']
# no hay precio mega Movistart

# %%
data[seleccion_variables].isnull().sum()
# Out:
# COD_NODO                             0
# FECHA                                0
# INVOLUNTARIO                         0
# CD_BLANCOS_CAMBIOS_SERVICIO          0
# AVG_TARIFA_TIGO                1362579
# AVG_TARIFA_ETB                 2624365
# AVG_TARIFA_MOVISTAR            1514298
# PROM_RENTA                       15507
# dtype: int64

# %%
data[seleccion_variables].isnull().sum()/len(data)
# Out:
# COD_NODO                       0.000000
# FECHA                          0.000000
# INVOLUNTARIO                   0.000000
# CD_BLANCOS_CAMBIOS_SERVICIO    0.000000
# AVG_TARIFA_TIGO                0.421279
# AVG_TARIFA_ETB                 0.811396
# AVG_TARIFA_MOVISTAR            0.468188
# PROM_RENTA                     0.004794
# dtype: float64

# %%
data[seleccion_variables].describe()
# Out:
#               FECHA  INVOLUNTARIO  CD_BLANCOS_CAMBIOS_SERVICIO  \
# count  3.234383e+06     3234383.0                    3234383.0
# mean   6.073886e+00           0.0                          0.0
# std    2.803414e+00           0.0                          0.0
# min    1.000000e+00           0.0                          0.0
# 25%    4.000000e+00           0.0                          0.0
# 50%    6.000000e+00           0.0                          0.0
# 75%    8.000000e+00           0.0                          0.0
# max    1.100000e+01           0.0                          0.0
#
#        AVG_TARIFA_TIGO  AVG_TARIFA_ETB  AVG_TARIFA_MOVISTAR    PROM_RENTA
# count     1.871804e+06   610018.000000         1.720085e+06  3.218876e+06
# mean      1.244205e+05    92561.595422         1.036952e+05  1.028364e+05
# std       1.254575e+04    19596.725265         9.651585e+03  1.751058e+04
# min       7.199000e+04    79900.000000         7.199000e+04  1.134200e+04
# 25%       1.180000e+05    79900.000000         9.790000e+04  9.085100e+04
# 50%       1.267850e+05    79900.000000         1.054000e+05  1.025950e+05
# 75%       1.300000e+05   111525.000000         1.129000e+05  1.123210e+05
# max       1.635700e+05   149900.000000         1.129000e+05  2.421450e+05

# %%
#alfa=com/nuestro

# %%
data_medida=data[seleccion_variables].copy()

# %%
variables_tarifa=['AVG_TARIFA_TIGO','AVG_TARIFA_ETB','AVG_TARIFA_MOVISTAR']

# %%
data_medida['comp_tarifa']=data_medida[variables_tarifa].min(axis=1)

# %%
data_medida['operador_menor_tarifa']=np.where(data_medida['comp_tarifa']==data_medida['AVG_TARIFA_TIGO'],'AVG_TARIFA_TIGO',
                                              np.where(data_medida['comp_tarifa']==data_medida['AVG_TARIFA_ETB'],'AVG_TARIFA_ETB',
                                                      np.where(data_medida['comp_tarifa']==data_medida['AVG_TARIFA_MOVISTAR'],'AVG_TARIFA_MOVISTAR','NINGUNO'
                                             )))

# %%
data_medida['ALFA_tarifa']=np.where(data_medida['operador_menor_tarifa']=='NINGUNO',np.nan,data_medida['comp_tarifa']/data_medida['PROM_RENTA'])

# %%
data_medida
# Out:
#         COD_NODO  FECHA  INVOLUNTARIO  CD_BLANCOS_CAMBIOS_SERVICIO  \
# 0            ZG2      8             0                            0
# 1           HBP1      3             0                            0
# 2          PPA4D      3             0                            0
# 3            9BZ      8             0                            0
# 4            SNJ      7             0                            0
# ...          ...    ...           ...                          ...
# 3748387      1GV     11             0                            0
# 3748388      CVB     11             0                            0
# 3748389      BTC      6             0                            0
# 3748390      P04      9             0                            0
# 3748391     4VU1     10             0                            0
#
#          AVG_TARIFA_TIGO  AVG_TARIFA_ETB  AVG_TARIFA_MOVISTAR  PROM_RENTA  \
# 0                    NaN             NaN                  NaN    133632.0
# 1                    NaN             NaN                  NaN    107735.0
# 2                    NaN             NaN                  NaN    102163.0
# 3          125714.285714         79900.0        108614.285714     89209.0
# 4          140000.000000             NaN        112900.000000    105915.0
# ...                  ...             ...                  ...         ...
# 3748387              NaN             NaN                  NaN     95346.0
# 3748388              NaN             NaN                  NaN    126325.0
# 3748389    126250.000000         79900.0        109150.000000     92790.0
# 3748390    135523.333333             NaN         90656.666667    103679.0
# 3748391              NaN             NaN                  NaN     93277.0
#
#            comp_tarifa operador_menor_tarifa  ALFA_tarifa
# 0                  NaN               NINGUNO          NaN
# 1                  NaN               NINGUNO          NaN
# 2                  NaN               NINGUNO          NaN
# 3         79900.000000        AVG_TARIFA_ETB     0.895650
# 4        112900.000000   AVG_TARIFA_MOVISTAR     1.065949
# ...                ...                   ...          ...
# 3748387            NaN               NINGUNO          NaN
# 3748388            NaN               NINGUNO          NaN
# 3748389   79900.000000        AVG_TARIFA_ETB     0.861084
# 3748390   90656.666667   AVG_TARIFA_MOVISTAR     0.874398
# 3748391            NaN               NINGUNO          NaN
#
# [3234383 rows x 11 columns]

# %%
resumen_medida=pd.pivot_table(data_medida[['FECHA','COD_NODO','ALFA_tarifa']], columns='FECHA', index='COD_NODO',aggfunc=np.mean)
resumen_medida.columns = resumen_medida.columns.droplevel()
resumen_medida
# Out:
# FECHA           1         2         3         4         5         6   \
# COD_NODO
# 01S            NaN       NaN  0.875348  0.871263  1.209064  0.863952
# 02S       1.274914  0.907934  1.277684  1.258177  1.259581  1.270295
# 0AL            NaN       NaN  0.738222       NaN  0.728679  0.539047
# 0AO       0.810964       NaN  0.988197  1.077074       NaN       NaN
# 0AR       1.284109  1.216581  1.298053  1.183848  1.104240  1.320534
# ...            ...       ...       ...       ...       ...       ...
# ZUL       1.063994       NaN  1.671811  1.072029  1.091996  1.088498
# ZVD       0.986515  0.960976  0.974316  0.979039  0.931441  0.957367
# ZVG       1.172341  1.176593  1.132425  1.066752  1.174378  1.166202
# ZVS       0.959760  1.121800  1.156596  1.157604  1.087080  1.102153
# ZVT            NaN  0.843362  0.623238  0.726892  0.622475       NaN
#
# FECHA           7         8         9         10
# COD_NODO
# 01S       0.860241       NaN       NaN  1.035875
# 02S       1.254361  0.909536  1.103387  0.957562
# 0AL       0.760157       NaN       NaN  0.474946
# 0AO            NaN       NaN  0.680075       NaN
# 0AR       1.172261  1.336661  1.033125  1.029064
# ...            ...       ...       ...       ...
# ZUL       1.090459  1.112140  1.159577  1.121575
# ZVD       0.953681  0.961424  0.894125  0.844062
# ZVG       1.072115  1.195050  1.040057  1.041562
# ZVS       1.101199  1.179469  1.024236  0.952015
# ZVT       0.623224  0.634243  0.755914  0.542212
#
# [9704 rows x 10 columns]

# %%
data_medida[data_medida['COD_NODO']=='01S'].sort_values('FECHA')
# Out:
#        COD_NODO  FECHA  INVOLUNTARIO  CD_BLANCOS_CAMBIOS_SERVICIO  \
# 958918      01S      1             0                            0
# 952438      01S      1             0                            0
# 955462      01S      1             0                            0
# 955750      01S      1             0                            0
# 932134      01S      1             0                            0
# ...         ...    ...           ...                          ...
# 955892      01S     11             0                            0
# 956036      01S     11             0                            0
# 960932      01S     11             0                            0
# 923636      01S     11             0                            0
# 953876      01S     11             0                            0
#
#         AVG_TARIFA_TIGO  AVG_TARIFA_ETB  AVG_TARIFA_MOVISTAR  PROM_RENTA  \
# 958918              NaN             NaN                  NaN     89601.0
# 952438              NaN             NaN                  NaN     89601.0
# 955462              NaN             NaN                  NaN     89601.0
# 955750              NaN             NaN                  NaN     89601.0
# 932134              NaN             NaN                  NaN     89601.0
# ...                 ...             ...                  ...         ...
# 955892              NaN             NaN                  NaN     90819.0
# 956036              NaN             NaN                  NaN     90819.0
# 960932              NaN             NaN                  NaN     90819.0
# 923636              NaN             NaN                  NaN     90819.0
# 953876              NaN             NaN                  NaN     90819.0
#
#         comp_tarifa operador_menor_tarifa  ALFA_tarifa
# 958918          NaN               NINGUNO          NaN
# 952438          NaN               NINGUNO          NaN
# 955462          NaN               NINGUNO          NaN
# 955750          NaN               NINGUNO          NaN
# 932134          NaN               NINGUNO          NaN
# ...             ...                   ...          ...
# 955892          NaN               NINGUNO          NaN
# 956036          NaN               NINGUNO          NaN
# 960932          NaN               NINGUNO          NaN
# 923636          NaN               NINGUNO          NaN
# 953876          NaN               NINGUNO          NaN
#
# [228 rows x 11 columns]

# %%
resumen_medida.isnull().sum()
# Out:
# FECHA
# 1     2963
# 2     3006
# 3     2811
# 4     2640
# 5     2765
# 6     2574
# 7     2342
# 8     2387
# 9     2071
# 10    2184
# dtype: int64

# %%
resumen_medida.isnull().sum()/len(resumen_medida)
# Out:
# FECHA
# 1     0.305338
# 2     0.309769
# 3     0.289674
# 4     0.272053
# 5     0.284934
# 6     0.265251
# 7     0.241344
# 8     0.245981
# 9     0.213417
# 10    0.225062
# dtype: float64

# %%
sns.violinplot(data=resumen_medida)
# Out:
# <AxesSubplot:xlabel='FECHA'>

# %%
resumen_medida['ene_oct']=resumen_medida[10]-resumen_medida[1]
resumen_medida['ene_may']=resumen_medida[5]-resumen_medida[1]

# %%
resumen_medida.describe()
# Out:
# FECHA            1            2            3            4            5  \
# count  6741.000000  6698.000000  6893.000000  7064.000000  6939.000000
# mean      0.986862     0.986459     0.986282     0.985155     0.989091
# std       0.222228     0.219783     0.218010     0.216290     0.218906
# min       0.424251     0.427115     0.443353     0.459624     0.432857
# 25%       0.824723     0.824866     0.828721     0.824852     0.829139
# 50%       0.976559     0.974808     0.974402     0.976436     0.977812
# 75%       1.127861     1.122591     1.120084     1.120176     1.123003
# max       2.567901     2.282624     2.918921     2.256057     2.353665
#
# FECHA            6            7            8            9           10  \
# count  7130.000000  7362.000000  7317.000000  7633.000000  7520.000000
# mean      0.985250     0.981769     1.007998     0.889634     0.896711
# std       0.217622     0.211938     0.214597     0.172056     0.169812
# min       0.421675     0.423495     0.432636     0.367525     0.346936
# 25%       0.826536     0.830247     0.854087     0.782884     0.790784
# 50%       0.973474     0.973728     0.998418     0.880032     0.887337
# 75%       1.117394     1.111162     1.135050     0.991742     0.997354
# max       2.362262     2.378556     2.472470     1.943738     1.918936
#
# FECHA      ene_oct      ene_may
# count  5716.000000  5517.000000
# mean     -0.096479    -0.007082
# std       0.170847     0.177239
# min      -0.964745    -1.020891
# 25%      -0.199995    -0.061030
# 50%      -0.111612     0.000709
# 75%       0.015904     0.047504
# max       0.371453     0.670422

# %%
sns.violinplot(data=resumen_medida)
# Out:
# <AxesSubplot:xlabel='FECHA'>

# %%
resumen_medida
# Out:
# FECHA            1         2         3         4         5         6  \
# COD_NODO
# 01S            NaN       NaN  0.875348  0.871263  1.209064  0.863952
# 02S       1.274914  0.907934  1.277684  1.258177  1.259581  1.270295
# 0AL            NaN       NaN  0.738222       NaN  0.728679  0.539047
# 0AO       0.810964       NaN  0.988197  1.077074       NaN       NaN
# 0AR       1.284109  1.216581  1.298053  1.183848  1.104240  1.320534
# ...            ...       ...       ...       ...       ...       ...
# ZUL       1.063994       NaN  1.671811  1.072029  1.091996  1.088498
# ZVD       0.986515  0.960976  0.974316  0.979039  0.931441  0.957367
# ZVG       1.172341  1.176593  1.132425  1.066752  1.174378  1.166202
# ZVS       0.959760  1.121800  1.156596  1.157604  1.087080  1.102153
# ZVT            NaN  0.843362  0.623238  0.726892  0.622475       NaN
#
# FECHA            7         8         9        10   ene_oct   ene_may
# COD_NODO
# 01S       0.860241       NaN       NaN  1.035875       NaN       NaN
# 02S       1.254361  0.909536  1.103387  0.957562 -0.317352 -0.015333
# 0AL       0.760157       NaN       NaN  0.474946       NaN       NaN
# 0AO            NaN       NaN  0.680075       NaN       NaN       NaN
# 0AR       1.172261  1.336661  1.033125  1.029064 -0.255045 -0.179869
# ...            ...       ...       ...       ...       ...       ...
# ZUL       1.090459  1.112140  1.159577  1.121575  0.057581  0.028003
# ZVD       0.953681  0.961424  0.894125  0.844062 -0.142453 -0.055074
# ZVG       1.072115  1.195050  1.040057  1.041562 -0.130779  0.002037
# ZVS       1.101199  1.179469  1.024236  0.952015 -0.007745  0.127320
# ZVT       0.623224  0.634243  0.755914  0.542212       NaN       NaN
#
# [9704 rows x 12 columns]

# %%
resumen_medida.isnull().sum()
# Out:
# FECHA
# 1          2963
# 2          3006
# 3          2811
# 4          2640
# 5          2765
# 6          2574
# 7          2342
# 8          2387
# 9          2071
# 10         2184
# ene_oct    3988
# ene_may    4187
# dtype: int64

# %%
resumen_medida.isnull().sum()/len(resumen_medida)
# Out:
# FECHA
# 1          0.305338
# 2          0.309769
# 3          0.289674
# 4          0.272053
# 5          0.284934
# 6          0.265251
# 7          0.241344
# 8          0.245981
# 9          0.213417
# 10         0.225062
# ene_oct    0.410965
# ene_may    0.431472
# dtype: float64

# %%
resumen_medida['bin_alfa']=pd.cut((resumen_medida['ene_oct']),bins=5,right=True)

# %%
resumen_medida['bin_alfa'].value_counts().to_frame().sort_index()
# Out:
#                   bin_alfa
# (-0.966, -0.698]         5
# (-0.698, -0.43]        119
# (-0.43, -0.163]       1772
# (-0.163, 0.104]       2823
# (0.104, 0.371]         997

# %% [markdown]
# ## opcion2

# %%
resumen_medida['ene_oct'].quantile(0.05)
# Out:
# -0.35964126925660145

# %%
corte=resumen_medida['ene_oct'].quantile(0.20)
corte
# Out:
# -0.23248164336784172

# %% [markdown]
# ###  Segunda parte

# %%
seleccionVariables=['CONGELACION','VIAJES','CAPACIDAD_DE_PAGO','CAUSAS_EXTERNAS','COMPETENCIA','MAL_SERVICIO','NO_UTILIZAR',
                    'NO_GUSTO','SIN_MOTIVO','SIN_CONTACTO','TRASLADOS','OTROS','CAMBIO_DE_SERVICIO','CAMBIO_TARIFA','EMPAQUETAMIENTO',
                    'CESION_DE_CONTRATO','UNIFICACION_EMPAQUETAMIENTO']

# Sin 'CD_BLANCOS_CAMBIOS_OTROS'

# %% [markdown]
# ### Pregunta
# * tome la diferencia de enero a oct.  Debo tomar el cambio de tendencia?

# %%
data_causal=data.merge(resumen_medida[['ene_oct']], left_on='COD_NODO', right_index=True, how='left')

# %%
data_causal['ET']=np.where(data_causal['ene_oct']<=corte,1,0)

# %%
data_causal['ET'].value_counts()
# Out:
# 0    2891534
# 1     342849
# Name: ET, dtype: int64

# %%
data_causal['ET'].value_counts()/len(data_causal)
# Out:
# 0    0.893999
# 1    0.106001
# Name: ET, dtype: float64

# %% [markdown]
# ## Fase 2
# * Caracterizar Casos Graves
# * Arboles

# %%
data_causal
# Out:
#            CUENTA COD_SERVICIO Velocidad Internet COD_NODO ESTRATO CARTERA  \
# 0        88384766          NB2         @       50      ZG2       3       0
# 1        92228220          DV3       NaN       60     HBP1       3       0
# 2        48074413          5BA       NaN        5    PPA4D       3       0
# 3         2139171          SUD         @       10      9BZ       2       0
# 4        14885225          D3V         @      160      SNJ       4       0
# ...           ...          ...       ...      ...      ...     ...     ...
# 3748387  90354179          PH5         @        5      1GV       2       0
# 3748388   8087598          CMB         @      100      CVB       4       0
# 3748389  71164933          R30         @       30      BTC       2       0
# 3748390  71189674          5BA         @        5      P04       4       0
# 3748391  42135323          MT3         @        8     4VU1       2       0
#
#          CONGELACION  VIAJES  CAPACIDAD_DE_PAGO  ...      MEGA  \
# 0                  0       0                  0  ...  0.714482
# 1                  0       0                  0  ...  0.414081
# 2                  0       0                  0  ...  2.877093
# 3                  0       0                  0  ...  1.108223
# 4                  0       0                  0  ...  1.006936
# ...              ...     ...                ...  ...       ...
# 3748387            0       0                  0  ...  1.686854
# 3748388            0       0                  0  ...  2.063867
# 3748389            0       0                  0  ...  0.441224
# 3748390            0       0                  0  ...  1.873057
# 3748391            0       0                  0  ...       NaN
#
#          NIVEL_ALARMA_MALO  NIVEL_ALARMA_BUENO             DIVISION  \
# 0                      0.0                 2.0  REGION NOROCCIDENTE
# 1                      0.0                 0.0        REGION CENTRO
# 2                      0.0                 0.0         REGION COSTA
# 3                      0.0                 3.0        REGION CENTRO
# 4                      0.0                 0.0       REGION ORIENTE
# ...                    ...                 ...                  ...
# 3748387                0.0                 2.0  REGION NOROCCIDENTE
# 3748388                0.0                 2.0       REGION ORIENTE
# 3748389                0.0                 0.0        REGION CENTRO
# 3748390                0.0                 1.0       REGION ORIENTE
# 3748391                0.0                 1.0        REGION CENTRO
#
#                      AREA                       ZONA         CIUDAD  \
# 0                MEDELLIN               MEDELLIN SUR       MEDELLIN
# 1        BOGOTA OCCIDENTE           SABANA OCCIDENTE         MADRID
# 2             COSTA NORTE                      CESAR     VALLEDUPAR
# 3              BOGOTA SUR                       BOSA         BOGOTA
# 4                  SANBOY  BUCARAMANGA-METROPOLITANA    BUCARAMANGA
# ...                   ...                        ...            ...
# 3748387          MEDELLIN             MEDELLIN NORTE          BELLO
# 3748388            SANBOY  BUCARAMANGA-METROPOLITANA  FLORIDABLANCA
# 3748389        BOGOTA SUR                       BOSA         BOGOTA
# 3748390            SANBOY  BUCARAMANGA-METROPOLITANA    BUCARAMANGA
# 3748391        BOGOTA SUR                   MADELENA         BOGOTA
#
#                      DISTRITO   ene_oct  ET
# 0        MEDELLIN SURORIENTAL       NaN   0
# 1                      MADRID       NaN   0
# 2            CESAR DISTRITO 1       NaN   0
# 3                        ROMA -0.139428   0
# 4              DISTRITO BGA 1       NaN   0
# ...                       ...       ...  ..
# 3748387           BELLO NORTE       NaN   0
# 3748388    DISTRITO FLORIDA 1       NaN   0
# 3748389                  ROMA  0.160395   0
# 3748390        DISTRITO BGA 3 -0.078399   0
# 3748391            EL ENSUE?O       NaN   0
#
# [3234383 rows x 89 columns]

# %%
data_causal[seleccionVariables].describe()
# Out:
#         CONGELACION        VIAJES  CAPACIDAD_DE_PAGO  CAUSAS_EXTERNAS  \
# count  3.234383e+06  3.234383e+06       3.234383e+06        3234383.0
# mean  -1.197384e-02 -5.859232e-03      -1.827458e-02              0.0
# std    1.117349e-01  7.663235e-02       1.349522e-01              0.0
# min   -4.000000e+00 -4.000000e+00      -4.000000e+00              0.0
# 25%    0.000000e+00  0.000000e+00       0.000000e+00              0.0
# 50%    0.000000e+00  0.000000e+00       0.000000e+00              0.0
# 75%    0.000000e+00  0.000000e+00       0.000000e+00              0.0
# max    0.000000e+00  0.000000e+00       0.000000e+00              0.0
#
#         COMPETENCIA  MAL_SERVICIO   NO_UTILIZAR      NO_GUSTO    SIN_MOTIVO  \
# count  3.234383e+06  3.234383e+06  3.234383e+06  3.234383e+06  3.234383e+06
# mean  -5.306422e-03 -1.519826e-02 -6.437395e-03 -3.817111e-03 -6.382639e-02
# std    7.302097e-02  1.230665e-01  8.042192e-02  6.222874e-02  2.462706e-01
# min   -4.000000e+00 -4.000000e+00 -4.000000e+00 -4.000000e+00 -6.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#        SIN_CONTACTO  TRASLADOS         OTROS  CAMBIO_DE_SERVICIO  \
# count  3.234383e+06  3234383.0  3.234383e+06           3234383.0
# mean  -1.855068e-06        0.0 -1.775609e-03                 0.0
# std    1.362008e-03        0.0  4.340232e-02                 0.0
# min   -1.000000e+00        0.0 -3.000000e+00                 0.0
# 25%    0.000000e+00        0.0  0.000000e+00                 0.0
# 50%    0.000000e+00        0.0  0.000000e+00                 0.0
# 75%    0.000000e+00        0.0  0.000000e+00                 0.0
# max    0.000000e+00        0.0  0.000000e+00                 0.0
#
#        CAMBIO_TARIFA  EMPAQUETAMIENTO  CESION_DE_CONTRATO  \
# count      3234383.0        3234383.0           3234383.0
# mean             0.0              0.0                 0.0
# std              0.0              0.0                 0.0
# min              0.0              0.0                 0.0
# 25%              0.0              0.0                 0.0
# 50%              0.0              0.0                 0.0
# 75%              0.0              0.0                 0.0
# max              0.0              0.0                 0.0
#
#        UNIFICACION_EMPAQUETAMIENTO
# count                 3.234383e+06
# mean                 -7.729449e-06
# std                   2.780178e-03
# min                  -1.000000e+00
# 25%                   0.000000e+00
# 50%                   0.000000e+00
# 75%                   0.000000e+00
# max                   0.000000e+00

# %%
data_causal[seleccionVariables]=data_causal[seleccionVariables]*-1

# %%
data_causal['BAJAS TOTAL']=data_causal[seleccionVariables].sum(axis=1)

# %%
#data_causal['ET','BAJAS TOTAL']
sns.violinplot(data=data_causal, x="ET", y="BAJAS TOTAL")
# Out:
# <AxesSubplot:xlabel='ET', ylabel='BAJAS TOTAL'>

# %%
data_causal[data_causal['ET']==1][seleccionVariables].sum().to_frame().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data_causal[data_causal['ET']==0][seleccionVariables].sum().to_frame().plot.bar()
# Out:
# <AxesSubplot:>

# %%
resumen_causa=data_causal[seleccionVariables].sum().to_frame()
resumen_causa=resumen_causa.merge(data_causal[data_causal['ET']==1][seleccionVariables].sum().to_frame(), left_index=True,right_index=True, how='left')
resumen_causa=resumen_causa.merge(data_causal[data_causal['ET']==0][seleccionVariables].sum().to_frame(), left_index=True,right_index=True, how='left')
resumen_causa.columns=['total','critico','normal']
resumen_causa
# Out:
#                               total  critico  normal
# CONGELACION                   38728     3853   34875
# VIAJES                        18951     1897   17054
# CAPACIDAD_DE_PAGO             59107     6529   52578
# CAUSAS_EXTERNAS                   0        0       0
# COMPETENCIA                   17163     1852   15311
# MAL_SERVICIO                  49157     5232   43925
# NO_UTILIZAR                   20821     2271   18550
# NO_GUSTO                      12346     1391   10955
# SIN_MOTIVO                   206439    22288  184151
# SIN_CONTACTO                      6        0       6
# TRASLADOS                         0        0       0
# OTROS                          5743      565    5178
# CAMBIO_DE_SERVICIO                0        0       0
# CAMBIO_TARIFA                     0        0       0
# EMPAQUETAMIENTO                   0        0       0
# CESION_DE_CONTRATO                0        0       0
# UNIFICACION_EMPAQUETAMIENTO      25        3      22

# %%
x = resumen_causa.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
resumen_causa_nor = pd.DataFrame(x_scaled)
resumen_causa_nor.index=resumen_causa.index
resumen_causa_nor.columns=resumen_causa.columns
resumen_causa_nor=resumen_causa_nor.sort_values('total', ascending=True)
resumen_causa_nor
# Out:
#                                 total   critico    normal
# EMPAQUETAMIENTO              0.000000  0.000000  0.000000
# CAUSAS_EXTERNAS              0.000000  0.000000  0.000000
# CAMBIO_TARIFA                0.000000  0.000000  0.000000
# CESION_DE_CONTRATO           0.000000  0.000000  0.000000
# TRASLADOS                    0.000000  0.000000  0.000000
# CAMBIO_DE_SERVICIO           0.000000  0.000000  0.000000
# SIN_CONTACTO                 0.000029  0.000000  0.000033
# UNIFICACION_EMPAQUETAMIENTO  0.000121  0.000135  0.000119
# OTROS                        0.027819  0.025350  0.028118
# NO_GUSTO                     0.059805  0.062410  0.059489
# COMPETENCIA                  0.083138  0.083094  0.083144
# VIAJES                       0.091800  0.085113  0.092609
# NO_UTILIZAR                  0.100858  0.101893  0.100733
# CONGELACION                  0.187600  0.172873  0.189383
# MAL_SERVICIO                 0.238119  0.234745  0.238527
# CAPACIDAD_DE_PAGO            0.286317  0.292938  0.285516
# SIN_MOTIVO                   1.000000  1.000000  1.000000

# %%
f = plt.figure()
resumen_causa_nor[['critico','normal']].plot.barh();
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
resumen_causa_nor['dif']=resumen_causa_nor['critico']-resumen_causa_nor['normal']

# %%
resumen_causa_nor=resumen_causa_nor.sort_values('dif', ascending=False)
resumen_causa_nor
# Out:
#                                 total   critico    normal       dif
# CAPACIDAD_DE_PAGO            0.286317  0.292938  0.285516  0.007422
# NO_GUSTO                     0.059805  0.062410  0.059489  0.002921
# NO_UTILIZAR                  0.100858  0.101893  0.100733  0.001161
# UNIFICACION_EMPAQUETAMIENTO  0.000121  0.000135  0.000119  0.000015
# EMPAQUETAMIENTO              0.000000  0.000000  0.000000  0.000000
# CAUSAS_EXTERNAS              0.000000  0.000000  0.000000  0.000000
# SIN_MOTIVO                   1.000000  1.000000  1.000000  0.000000
# CAMBIO_DE_SERVICIO           0.000000  0.000000  0.000000  0.000000
# TRASLADOS                    0.000000  0.000000  0.000000  0.000000
# CESION_DE_CONTRATO           0.000000  0.000000  0.000000  0.000000
# CAMBIO_TARIFA                0.000000  0.000000  0.000000  0.000000
# SIN_CONTACTO                 0.000029  0.000000  0.000033 -0.000033
# COMPETENCIA                  0.083138  0.083094  0.083144 -0.000050
# OTROS                        0.027819  0.025350  0.028118 -0.002768
# MAL_SERVICIO                 0.238119  0.234745  0.238527 -0.003782
# VIAJES                       0.091800  0.085113  0.092609 -0.007496
# CONGELACION                  0.187600  0.172873  0.189383 -0.016509

# %%
# Diferencia entre críticos y normales
resumen_causa_nor[['dif']].plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## ARBOL

# %%
def visualizarArbol(model_fit,depth):
    fig, ax = plt.subplots(figsize=(depth*10,10))
    print(f"Profundidad del árbol: {tree_model.get_depth()}")
    print(f"Número de nodos terminales: {tree_model.get_n_leaves()}")
    plot = plot_tree(
                decision_tree = tree_model,
                feature_names = seleccionVariables,
                class_names   = ['normal','critico'],
                filled        = True,
                impurity      = False,
                fontsize      = 10,
                precision     = 3,
                ax            = ax
           )

# %%
tree_model = DecisionTreeClassifier(random_state=0, max_depth=5,min_samples_leaf=500, class_weight='balanced')
model_fit = tree_model.fit(X = data_causal[seleccionVariables], y = data_causal["ET"])
visualizarArbol(model_fit,3)
# Out:
# Profundidad del árbol: 5
# Número de nodos terminales: 8

# %% [markdown]
# ## INVOLUNTARIOS

# %%
data=data_total[data_total['INVOLUNTARIO']==-1]

# %%
seleccion_variables=['COD_NODO','FECHA','INVOLUNTARIO','CD_BLANCOS_CAMBIOS_SERVICIO','AVG_TARIFA_TIGO','AVG_TARIFA_ETB','AVG_TARIFA_MOVISTAR','PROM_RENTA']
# no hay precio mega Movistart

# %%
data[seleccion_variables].isnull().sum()
# Out:
# COD_NODO                            0
# FECHA                               0
# INVOLUNTARIO                        0
# CD_BLANCOS_CAMBIOS_SERVICIO         0
# AVG_TARIFA_TIGO                265783
# AVG_TARIFA_ETB                 432261
# AVG_TARIFA_MOVISTAR            291345
# PROM_RENTA                      41354
# dtype: int64

# %%
data[seleccion_variables].isnull().sum()/len(data)
# Out:
# COD_NODO                       0.000000
# FECHA                          0.000000
# INVOLUNTARIO                   0.000000
# CD_BLANCOS_CAMBIOS_SERVICIO    0.000000
# AVG_TARIFA_TIGO                0.517078
# AVG_TARIFA_ETB                 0.840960
# AVG_TARIFA_MOVISTAR            0.566809
# PROM_RENTA                     0.080454
# dtype: float64

# %%
data[seleccion_variables].describe()
# Out:
#                FECHA  INVOLUNTARIO  CD_BLANCOS_CAMBIOS_SERVICIO  \
# count  514009.000000      514009.0                     514009.0
# mean        6.223449          -1.0                          0.0
# std         3.295587           0.0                          0.0
# min         1.000000          -1.0                          0.0
# 25%         3.000000          -1.0                          0.0
# 50%         6.000000          -1.0                          0.0
# 75%         9.000000          -1.0                          0.0
# max        11.000000          -1.0                          0.0
#
#        AVG_TARIFA_TIGO  AVG_TARIFA_ETB  AVG_TARIFA_MOVISTAR     PROM_RENTA
# count    248226.000000    81748.000000        222664.000000  472655.000000
# mean     120986.114649    95812.646018        102185.801468   94505.438578
# std       14057.918865    20415.262806         10002.996185   14781.706660
# min       71990.000000    79900.000000         71990.000000   11342.000000
# 25%      112000.000000    79900.000000         96878.888889   85490.000000
# 50%      124000.000000    79900.000000        102900.000000   93641.000000
# 75%      130000.000000   117400.000000        112900.000000  104594.000000
# max      163570.000000   149900.000000        112900.000000  231390.000000

# %%
#alfa=com/nuestro

# %%
data_medida=data[seleccion_variables].copy()

# %%
variables_tarifa=['AVG_TARIFA_TIGO','AVG_TARIFA_ETB','AVG_TARIFA_MOVISTAR']

# %%
data_medida['comp_tarifa']=data_medida[variables_tarifa].min(axis=1)

# %%
data_medida['operador_menor_tarifa']=np.where(data_medida['comp_tarifa']==data_medida['AVG_TARIFA_TIGO'],'AVG_TARIFA_TIGO',
                                              np.where(data_medida['comp_tarifa']==data_medida['AVG_TARIFA_ETB'],'AVG_TARIFA_ETB',
                                                      np.where(data_medida['comp_tarifa']==data_medida['AVG_TARIFA_MOVISTAR'],'AVG_TARIFA_MOVISTAR','NINGUNO'
                                             )))

# %%
data_medida['ALFA_tarifa']=np.where(data_medida['operador_menor_tarifa']=='NINGUNO',np.nan,data_medida['comp_tarifa']/data_medida['PROM_RENTA'])

# %%
data_medida
# Out:
#         COD_NODO  FECHA  INVOLUNTARIO  CD_BLANCOS_CAMBIOS_SERVICIO  \
# 9            UD4     11            -1                            0
# 24          LOM1      2            -1                            0
# 28           GIT      4            -1                            0
# 32           BAB      1            -1                            0
# 53           IEL     11            -1                            0
# ...          ...    ...           ...                          ...
# 3748338      1GV     11            -1                            0
# 3748346      PAN      2            -1                            0
# 3748353      GA5      5            -1                            0
# 3748359      SVI      2            -1                            0
# 3748383      SVI      2            -1                            0
#
#          AVG_TARIFA_TIGO  AVG_TARIFA_ETB  AVG_TARIFA_MOVISTAR  PROM_RENTA  \
# 9                    NaN             NaN                  NaN     94282.0
# 24         130000.000000             NaN        112900.000000     89010.0
# 28         117142.857143             NaN        100042.857143     80274.0
# 32         115000.000000         79900.0         97900.000000    108907.0
# 53                   NaN             NaN                  NaN     75574.0
# ...                  ...             ...                  ...         ...
# 3748338              NaN             NaN                  NaN     95346.0
# 3748346    100000.000000             NaN         82900.000000    109801.0
# 3748353    122500.000000         79900.0        105400.000000    108388.0
# 3748359    130000.000000             NaN        112900.000000     96159.0
# 3748383    130000.000000             NaN        112900.000000     96159.0
#
#            comp_tarifa operador_menor_tarifa  ALFA_tarifa
# 9                  NaN               NINGUNO          NaN
# 24       112900.000000   AVG_TARIFA_MOVISTAR     1.268397
# 28       100042.857143   AVG_TARIFA_MOVISTAR     1.246267
# 32        79900.000000        AVG_TARIFA_ETB     0.733653
# 53                 NaN               NINGUNO          NaN
# ...                ...                   ...          ...
# 3748338            NaN               NINGUNO          NaN
# 3748346   82900.000000   AVG_TARIFA_MOVISTAR     0.755002
# 3748353   79900.000000        AVG_TARIFA_ETB     0.737166
# 3748359  112900.000000   AVG_TARIFA_MOVISTAR     1.174097
# 3748383  112900.000000   AVG_TARIFA_MOVISTAR     1.174097
#
# [514009 rows x 11 columns]

# %%
resumen_medida=pd.pivot_table(data_medida[['FECHA','COD_NODO','ALFA_tarifa']], columns='FECHA', index='COD_NODO',aggfunc=np.mean)
resumen_medida.columns = resumen_medida.columns.droplevel()
resumen_medida
# Out:
# FECHA           1         2         3         4         5         6   \
# COD_NODO
# 01S            NaN       NaN  0.875348  0.871263  1.209064  0.863952
# 02S       1.274914  0.907934  1.277684  1.258177  1.259581  1.270295
# 0AL            NaN       NaN       NaN       NaN  0.728679       NaN
# 0AO            NaN       NaN       NaN  1.077074       NaN       NaN
# 0AR       1.284109  1.216581  1.298053  1.183848  1.104240  1.320534
# ...            ...       ...       ...       ...       ...       ...
# ZUL       1.063994       NaN  1.671811  1.072029  1.091996  1.088498
# ZVD       0.986515  0.960976  0.974316  0.979039  0.931441  0.957367
# ZVG       1.172341  1.176593  1.132425  1.066752  1.174378  1.166202
# ZVS       0.959760  1.121800  1.156596  1.157604  1.087080  1.102153
# ZVT            NaN       NaN       NaN  0.726892  0.622475       NaN
#
# FECHA           7         8         9         10
# COD_NODO
# 01S       0.860241       NaN       NaN  1.035875
# 02S       1.254361  0.909536  1.103387  0.957562
# 0AL            NaN       NaN       NaN  0.474946
# 0AO            NaN       NaN       NaN       NaN
# 0AR       1.172261       NaN  1.033125  1.029064
# ...            ...       ...       ...       ...
# ZUL       1.090459       NaN  1.159577  1.121575
# ZVD       0.953681       NaN  0.894125  0.844062
# ZVG       1.072115  1.195050  1.040057  1.041562
# ZVS       1.101199       NaN  1.024236  0.952015
# ZVT       0.623224       NaN       NaN       NaN
#
# [8506 rows x 10 columns]

# %%
data_medida[data_medida['COD_NODO']=='01S'].sort_values('FECHA')
# Out:
#         COD_NODO  FECHA  INVOLUNTARIO  CD_BLANCOS_CAMBIOS_SERVICIO  \
# 959350       01S      1            -1                            0
# 1020694      01S      1            -1                            0
# 993910       01S      1            -1                            0
# 925942       01S      1            -1                            0
# 11134        01S      2            -1                            0
# ...          ...    ...           ...                          ...
# 941924       01S     11            -1                            0
# 941492       01S     11            -1                            0
# 935732       01S     11            -1                            0
# 903764       01S     11            -1                            0
# 898292       01S     11            -1                            0
#
#          AVG_TARIFA_TIGO  AVG_TARIFA_ETB  AVG_TARIFA_MOVISTAR  PROM_RENTA  \
# 959350               NaN             NaN                  NaN     89601.0
# 1020694              NaN             NaN                  NaN     89601.0
# 993910               NaN             NaN                  NaN     89601.0
# 925942               NaN             NaN                  NaN     89601.0
# 11134                NaN             NaN                  NaN     90711.0
# ...                  ...             ...                  ...         ...
# 941924               NaN             NaN                  NaN     90819.0
# 941492               NaN             NaN                  NaN     90819.0
# 935732               NaN             NaN                  NaN     90819.0
# 903764               NaN             NaN                  NaN     90819.0
# 898292               NaN             NaN                  NaN     90819.0
#
#          comp_tarifa operador_menor_tarifa  ALFA_tarifa
# 959350           NaN               NINGUNO          NaN
# 1020694          NaN               NINGUNO          NaN
# 993910           NaN               NINGUNO          NaN
# 925942           NaN               NINGUNO          NaN
# 11134            NaN               NINGUNO          NaN
# ...              ...                   ...          ...
# 941924           NaN               NINGUNO          NaN
# 941492           NaN               NINGUNO          NaN
# 935732           NaN               NINGUNO          NaN
# 903764           NaN               NINGUNO          NaN
# 898292           NaN               NINGUNO          NaN
#
# [65 rows x 11 columns]

# %%
resumen_medida.isnull().sum()
# Out:
# FECHA
# 1     3384
# 2     3689
# 3     3569
# 4     3443
# 5     3277
# 6     3359
# 7     3084
# 8     7173
# 9     2368
# 10    2673
# dtype: int64

# %%
resumen_medida.isnull().sum()/len(resumen_medida)
# Out:
# FECHA
# 1     0.397837
# 2     0.433694
# 3     0.419586
# 4     0.404773
# 5     0.385257
# 6     0.394898
# 7     0.362568
# 8     0.843287
# 9     0.278392
# 10    0.314249
# dtype: float64

# %%
sns.violinplot(data=resumen_medida)
# Out:
# <AxesSubplot:xlabel='FECHA'>

# %%
resumen_medida['ene_oct']=resumen_medida[10]-resumen_medida[1]
resumen_medida['ene_may']=resumen_medida[5]-resumen_medida[1]

# %%
resumen_medida.describe()
# Out:
# FECHA            1            2            3            4            5  \
# count  5122.000000  4817.000000  4937.000000  5063.000000  5229.000000
# mean      1.025305     1.030343     1.031956     1.025179     1.029701
# std       0.223148     0.221337     0.217072     0.216118     0.218237
# min       0.450003     0.493676     0.475745     0.466443     0.515531
# 25%       0.864059     0.869064     0.878699     0.869432     0.872566
# 50%       1.014120     1.017209     1.020117     1.017530     1.018974
# 75%       1.174363     1.178140     1.177636     1.168661     1.171372
# max       2.567901     2.282624     2.302515     2.256057     2.353665
#
# FECHA            6            7            8            9           10  \
# count  5147.000000  5422.000000  1333.000000  6138.000000  5833.000000
# mean      1.026143     1.018659     1.098351     0.921733     0.934736
# std       0.219871     0.212693     0.212232     0.164049     0.159878
# min       0.443615     0.435068     0.600706     0.367525     0.421670
# 25%       0.862944     0.869966     0.958174     0.819999     0.833521
# 50%       1.016341     1.008625     1.084405     0.906801     0.918679
# 75%       1.170336     1.153175     1.230987     1.020806     1.030562
# max       2.362262     2.378556     1.976976     1.943738     1.918936
#
# FECHA      ene_oct      ene_may
# count  4127.000000  3987.000000
# mean     -0.096583    -0.009041
# std       0.179495     0.185980
# min      -0.964745    -1.020891
# 25%      -0.206837    -0.059284
# 50%      -0.119835     0.000203
# 75%       0.036485     0.045928
# max       0.371453     0.670422

# %%
sns.violinplot(data=resumen_medida)
# Out:
# <AxesSubplot:xlabel='FECHA'>

# %%
resumen_medida
# Out:
# FECHA            1         2         3         4         5         6  \
# COD_NODO
# 01S            NaN       NaN  0.875348  0.871263  1.209064  0.863952
# 02S       1.274914  0.907934  1.277684  1.258177  1.259581  1.270295
# 0AL            NaN       NaN       NaN       NaN  0.728679       NaN
# 0AO            NaN       NaN       NaN  1.077074       NaN       NaN
# 0AR       1.284109  1.216581  1.298053  1.183848  1.104240  1.320534
# ...            ...       ...       ...       ...       ...       ...
# ZUL       1.063994       NaN  1.671811  1.072029  1.091996  1.088498
# ZVD       0.986515  0.960976  0.974316  0.979039  0.931441  0.957367
# ZVG       1.172341  1.176593  1.132425  1.066752  1.174378  1.166202
# ZVS       0.959760  1.121800  1.156596  1.157604  1.087080  1.102153
# ZVT            NaN       NaN       NaN  0.726892  0.622475       NaN
#
# FECHA            7         8         9        10   ene_oct   ene_may
# COD_NODO
# 01S       0.860241       NaN       NaN  1.035875       NaN       NaN
# 02S       1.254361  0.909536  1.103387  0.957562 -0.317352 -0.015333
# 0AL            NaN       NaN       NaN  0.474946       NaN       NaN
# 0AO            NaN       NaN       NaN       NaN       NaN       NaN
# 0AR       1.172261       NaN  1.033125  1.029064 -0.255045 -0.179869
# ...            ...       ...       ...       ...       ...       ...
# ZUL       1.090459       NaN  1.159577  1.121575  0.057581  0.028003
# ZVD       0.953681       NaN  0.894125  0.844062 -0.142453 -0.055074
# ZVG       1.072115  1.195050  1.040057  1.041562 -0.130779  0.002037
# ZVS       1.101199       NaN  1.024236  0.952015 -0.007745  0.127320
# ZVT       0.623224       NaN       NaN       NaN       NaN       NaN
#
# [8506 rows x 12 columns]

# %%
resumen_medida.isnull().sum()
# Out:
# FECHA
# 1          3384
# 2          3689
# 3          3569
# 4          3443
# 5          3277
# 6          3359
# 7          3084
# 8          7173
# 9          2368
# 10         2673
# ene_oct    4379
# ene_may    4519
# dtype: int64

# %%
resumen_medida.isnull().sum()/len(resumen_medida)
# Out:
# FECHA
# 1          0.397837
# 2          0.433694
# 3          0.419586
# 4          0.404773
# 5          0.385257
# 6          0.394898
# 7          0.362568
# 8          0.843287
# 9          0.278392
# 10         0.314249
# ene_oct    0.514813
# ene_may    0.531272
# dtype: float64

# %%
resumen_medida['bin_alfa']=pd.cut((resumen_medida['ene_oct']),bins=5,right=True)

# %%
resumen_medida['bin_alfa'].value_counts().to_frame().sort_index()
# Out:
#                   bin_alfa
# (-0.966, -0.698]         5
# (-0.698, -0.43]         96
# (-0.43, -0.163]       1362
# (-0.163, 0.104]       1866
# (0.104, 0.371]         798

# %% [markdown]
# ## opcion2

# %%
resumen_medida['ene_oct'].quantile(0.05)
# Out:
# -0.36973423859158505

# %%
corte=resumen_medida['ene_oct'].quantile(0.20)
corte
# Out:
# -0.23872831347323645

# %% [markdown]
# ###  Segunda parte

# %%
seleccionVariables=['CONGELACION','VIAJES','CAPACIDAD_DE_PAGO','CAUSAS_EXTERNAS','COMPETENCIA','MAL_SERVICIO','NO_UTILIZAR',
                    'NO_GUSTO','SIN_MOTIVO','SIN_CONTACTO','TRASLADOS','OTROS','CAMBIO_DE_SERVICIO','CAMBIO_TARIFA','EMPAQUETAMIENTO',
                    'CESION_DE_CONTRATO','UNIFICACION_EMPAQUETAMIENTO']

# Sin 'CD_BLANCOS_CAMBIOS_OTROS'

# %% [markdown]
# ### Pregunta
# * tome la diferencia de enero a oct.  Debo tomar el cambio de tendencia?

# %%
(data[seleccionVariables]==0).sum()
# Out:
# CONGELACION                    496343
# VIAJES                         513464
# CAPACIDAD_DE_PAGO              513808
# CAUSAS_EXTERNAS                512436
# COMPETENCIA                    514009
# MAL_SERVICIO                   513697
# NO_UTILIZAR                    512388
# NO_GUSTO                       513497
# SIN_MOTIVO                     513732
# SIN_CONTACTO                   509407
# TRASLADOS                      514009
# OTROS                          513467
# CAMBIO_DE_SERVICIO             514009
# CAMBIO_TARIFA                  513760
# EMPAQUETAMIENTO                514009
# CESION_DE_CONTRATO             514009
# UNIFICACION_EMPAQUETAMIENTO    513815
# dtype: int64

# %%
data_causal=data.merge(resumen_medida[['ene_oct']], left_on='COD_NODO', right_index=True, how='left')

# %%
data_causal['ET']=np.where(data_causal['ene_oct']<=corte,1,0)

# %%
data_causal['ET'].value_counts()
# Out:
# 0    460217
# 1     53792
# Name: ET, dtype: int64

# %%
data_causal['ET'].value_counts()/len(data_causal)
# Out:
# 0    0.895348
# 1    0.104652
# Name: ET, dtype: float64

# %% [markdown]
# ## Fase 2
# * Caracterizar Casos Graves
# * Arboles

# %%
data_causal
# Out:
#            CUENTA COD_SERVICIO Velocidad Internet COD_NODO ESTRATO CARTERA  \
# 9        30223636          MH1         @       15      UD4       2      -1
# 24       24894327          R30         @       30     LOM1       2      -1
# 28       36942049          RQM         @       15      GIT       1      -1
# 32       28544974          BC7         @       75      BAB       3      -1
# 53       42058061          MH2         @       23      IEL       2      -1
# ...           ...          ...       ...      ...      ...     ...     ...
# 3748338  70261516          NB2         @       50      1GV       2      -1
# 3748346  83007724          RB3         @       30      PAN       3      -1
# 3748353  79554518          D3V         @      160      GA5       3      -1
# 3748359  25691003          PH5         @        5      SVI       2      -1
# 3748383  36539142          R08         @        8      SVI       2      -1
#
#          CONGELACION  VIAJES  CAPACIDAD_DE_PAGO  ...      MEGA  \
# 9                  0       0                  0  ...  0.576565
# 24                 0       0                  0  ...  0.872224
# 28                 0       0                  0  ...  1.473971
# 32                 0       0                  0  ...  0.643162
# 53                 0       0                  0  ...  0.054032
# ...              ...     ...                ...  ...       ...
# 3748338            0       0                  0  ...  1.686854
# 3748346            0       0                  0  ...  1.752191
# 3748353            0       0                  0  ...       NaN
# 3748359            0       0                  0  ...  1.056041
# 3748383            0       0                  0  ...  1.056041
#
#          NIVEL_ALARMA_MALO  NIVEL_ALARMA_BUENO             DIVISION  \
# 9                      1.0                 0.0         REGION COSTA
# 24                     0.0                 0.0       REGION ORIENTE
# 28                     0.0                 0.0     REGION OCCIDENTE
# 32                     0.0                 0.0        REGION CENTRO
# 53                     0.0                 2.0       REGION ORIENTE
# ...                    ...                 ...                  ...
# 3748338                0.0                 2.0  REGION NOROCCIDENTE
# 3748346                0.0                 0.0     REGION OCCIDENTE
# 3748353                0.0                 0.0        REGION CENTRO
# 3748359                0.0                 0.0        REGION CENTRO
# 3748383                0.0                 0.0        REGION CENTRO
#
#                      AREA                ZONA        CIUDAD  \
# 9             COSTA NORTE      BARRANQUILLA 1  BARRANQUILLA
# 24                 SANBOY  NORTE DE SANTANDER        CUCUTA
# 28                TOLHUCA              TOLIMA        IBAGUE
# 32             BOGOTA SUR                BOSA        BOGOTA
# 53                 SANBOY  NORTE DE SANTANDER        CUCUTA
# ...                   ...                 ...           ...
# 3748338          MEDELLIN      MEDELLIN NORTE         BELLO
# 3748346              CALI            CALI SUR          CALI
# 3748353    BOGOTA ORIENTE               GALAN        BOGOTA
# 3748359  BOGOTA OCCIDENTE            FONTIBON        BOGOTA
# 3748383  BOGOTA OCCIDENTE            FONTIBON        BOGOTA
#
#                           DISTRITO   ene_oct  ET
# 9        BARRANQUILLA 1 DISTRITO 4 -0.247604   1
# 24               DISTRITO CUCUTA 4 -0.118797   0
# 28               TOLIMA DISTRITO 2  0.192738   0
# 32                            ROMA  0.186336   0
# 53               DISTRITO CUCUTA 4 -0.142559   0
# ...                            ...       ...  ..
# 3748338                BELLO NORTE       NaN   0
# 3748346        CALI SUR DISTRITO 4 -0.079492   0
# 3748353                   AMERICAS  0.099258   0
# 3748359                   ENGATIVA       NaN   0
# 3748383                   ENGATIVA       NaN   0
#
# [514009 rows x 89 columns]

# %%
data_causal[seleccionVariables].describe()
# Out:
#          CONGELACION         VIAJES  CAPACIDAD_DE_PAGO  CAUSAS_EXTERNAS  \
# count  514009.000000  514009.000000      514009.000000    514009.000000
# mean       -0.034383      -0.001078          -0.000391        -0.003078
# std         0.182807       0.033342           0.019771         0.055812
# min        -9.000000      -2.000000          -1.000000        -4.000000
# 25%         0.000000       0.000000           0.000000         0.000000
# 50%         0.000000       0.000000           0.000000         0.000000
# 75%         0.000000       0.000000           0.000000         0.000000
# max         1.000000       0.000000           0.000000         0.000000
#
#        COMPETENCIA   MAL_SERVICIO    NO_UTILIZAR      NO_GUSTO     SIN_MOTIVO  \
# count     514009.0  514009.000000  514009.000000  514009.00000  514009.000000
# mean           0.0      -0.000609      -0.003173      -0.00100      -0.000545
# std            0.0       0.024748       0.056586       0.03173       0.023664
# min            0.0      -2.000000      -2.000000      -2.00000      -3.000000
# 25%            0.0       0.000000       0.000000       0.00000       0.000000
# 50%            0.0       0.000000       0.000000       0.00000       0.000000
# 75%            0.0       0.000000       0.000000       0.00000       0.000000
# max            0.0       0.000000       0.000000       0.00000       0.000000
#
#         SIN_CONTACTO  TRASLADOS          OTROS  CAMBIO_DE_SERVICIO  \
# count  514009.000000   514009.0  514009.000000            514009.0
# mean       -0.008990        0.0      -0.001058                 0.0
# std         0.094842        0.0       0.032635                 0.0
# min        -4.000000        0.0      -2.000000                 0.0
# 25%         0.000000        0.0       0.000000                 0.0
# 50%         0.000000        0.0       0.000000                 0.0
# 75%         0.000000        0.0       0.000000                 0.0
# max         0.000000        0.0       0.000000                 0.0
#
#        CAMBIO_TARIFA  EMPAQUETAMIENTO  CESION_DE_CONTRATO  \
# count  514009.000000         514009.0            514009.0
# mean       -0.000523              0.0                 0.0
# std         0.024671              0.0                 0.0
# min        -3.000000              0.0                 0.0
# 25%         0.000000              0.0                 0.0
# 50%         0.000000              0.0                 0.0
# 75%         0.000000              0.0                 0.0
# max         0.000000              0.0                 0.0
#
#        UNIFICACION_EMPAQUETAMIENTO
# count                514009.000000
# mean                     -0.000387
# std                       0.020161
# min                      -2.000000
# 25%                       0.000000
# 50%                       0.000000
# 75%                       0.000000
# max                       0.000000

# %%
data_causal[seleccionVariables]=data_causal[seleccionVariables]*-1

# %%
data_causal['BAJAS TOTAL']=data_causal[seleccionVariables].sum(axis=1)

# %%
#data_causal['ET','BAJAS TOTAL']
sns.violinplot(data=data_causal, x="ET", y="BAJAS TOTAL")
# Out:
# <AxesSubplot:xlabel='ET', ylabel='BAJAS TOTAL'>

# %%
data_causal[(data_causal['BAJAS TOTAL']>0)&(data_causal['ET']==1)]
# Out:
# Empty DataFrame
# Columns: [CUENTA, COD_SERVICIO, Velocidad, Internet, COD_NODO, ESTRATO, CARTERA, CONGELACION, VIAJES, CAPACIDAD_DE_PAGO, CAUSAS_EXTERNAS, COMPETENCIA, MAL_SERVICIO, NO_UTILIZAR, NO_GUSTO, SIN_MOTIVO, SIN_CONTACTO, TRASLADOS, OTROS, CD_BLANCOS_CAMBIOS_OTROS, CAMBIO_DE_SERVICIO, CAMBIO_TARIFA, EMPAQUETAMIENTO, CESION_DE_CONTRATO, UNIFICACION_EMPAQUETAMIENTO, CD_BLANCOS_CAMBIOS_SERVICIO, FECHA, CHURN_TEMPRANO, INVOLUNTARIO, VOLUNTARIO, TIPO_RAZON, CANTIDAD_LLAMADAS, CANTIDAD_ADMIN, CANTIDAD_TECNICO, CAMPANA_HBO, CAMPANA_FOX, CAMPANA_ADULTO, CAMPANA_EQUIPOS_ADIC, CAMPANA_ULTRAWIFI, CAMPANA_VOZ, CAMPANA_RETENCION, CAMPANA_AFECTACION_SRV, PART_CANT_CALL, CANT_USER, PROM_VEL, VEL_ME_8, VEL_10_25, VEL_30, VEL_40_50, VEL_MA_60, CONVERGENTE, PROM_VEL_HOGAR, MEDIANA_VEL, PROM_RENTA, PRECIO_MEGA_CLARO_1, CANTIDAD_churn, ANTIGUEDAD_MESES_PROM, ANTIGUEDAD_MESES_MED, AVG_TARIFA_TIGO, AVG_TIGO_MEGAS, PRECIO_MEGA_TIGO_1, AVG_TARIFA_ETB, AVG_ETB_MEGAS, PRECIO_MEGA_ETB_1, AVG_TARIFA_MOVISTAR, AVG_MOVISTAR_MEGAS, AVG_MOV_MEGAS, OPERADOR_TIGO_OOKLA, OPERADOR_ETB_OOKLA, OPERADOR_MOVISTAR_OOKLA, SUMA_OPERADORES, RANK1_VEL_DWLD, OP_CLARO, CANTIDAD, PENETRACION, OCUPACION_DW, OCUPACION_UP, ALFA, BETA, MEGA, NIVEL_ALARMA_MALO, NIVEL_ALARMA_BUENO, DIVISION, AREA, ZONA, CIUDAD, DISTRITO, ene_oct, ET, BAJAS TOTAL]
# Index: []
#
# [0 rows x 90 columns]

# %%
data_causal[data_causal['ET']==1]
# Out:
#            CUENTA COD_SERVICIO Velocidad Internet COD_NODO ESTRATO CARTERA  \
# 9        30223636          MH1         @       15      UD4       2      -1
# 110      13781839          R30         @       30      BE2       2      -1
# 119      39673336          TP3         @       30      LIL       2      -1
# 268      87301826          NB3         @      100      RV1       3      -1
# 364      82350257          BC7         @       75     I1S1       2      -1
# ...           ...          ...       ...      ...      ...     ...     ...
# 3746725  28180335          R75         @       75      JSO       3      -1
# 3746919  21171406          NB3         @      100      PYR       3      -1
# 3747045   5632255          R1R         @       15      PYR       3      -1
# 3747519  25408119          D1V         @       60      PYR       3      -1
# 3747615  43914213          TP3         @       30      JSO       2      -1
#
#          CONGELACION  VIAJES  CAPACIDAD_DE_PAGO  ...  NIVEL_ALARMA_MALO  \
# 9                  0       0                  0  ...                1.0
# 110                0       0                  0  ...                0.0
# 119                0       0                  0  ...                2.0
# 268                0       0                  0  ...                0.0
# 364                0       0                  0  ...                0.0
# ...              ...     ...                ...  ...                ...
# 3746725            0       0                  0  ...                0.0
# 3746919            0       0                  0  ...                0.0
# 3747045            0       0                  0  ...                0.0
# 3747519            0       0                  0  ...                0.0
# 3747615            0       0                  0  ...                0.0
#
#          NIVEL_ALARMA_BUENO             DIVISION          AREA  \
# 9                       0.0         REGION COSTA   COSTA NORTE
# 110                     0.0        REGION CENTRO    BOGOTA SUR
# 119                     0.0     REGION OCCIDENTE        VACANA
# 268                     5.0  REGION NOROCCIDENTE  EJE CAFETERO
# 364                     0.0        REGION CENTRO    BOGOTA SUR
# ...                     ...                  ...           ...
# 3746725                 0.0       REGION ORIENTE        SANBOY
# 3746919                 0.0  REGION NOROCCIDENTE      MEDELLIN
# 3747045                 0.0  REGION NOROCCIDENTE      MEDELLIN
# 3747519                 0.0  REGION NOROCCIDENTE      MEDELLIN
# 3747615                 0.0       REGION ORIENTE        SANBOY
#
#                    ZONA        CIUDAD                   DISTRITO   ene_oct  \
# 9        BARRANQUILLA 1  BARRANQUILLA  BARRANQUILLA 1 DISTRITO 4 -0.247604
# 110                BOSA        BOGOTA                FERROCARRIL -0.307819
# 119               VALLE         TULUA           VALLE DISTRITO 4 -0.247821
# 268              CALDAS     MANIZALES          MANIZALES CALDAS4 -0.316593
# 364            MADELENA        BOGOTA                  ALEJANDRA -0.263304
# ...                 ...           ...                        ...       ...
# 3746725          BOYACA         TUNJA                  TUNJA SUR -0.519051
# 3746919    MEDELLIN SUR      MEDELLIN       MEDELLIN SURORIENTAL -0.247381
# 3747045    MEDELLIN SUR      MEDELLIN       MEDELLIN SURORIENTAL -0.247381
# 3747519    MEDELLIN SUR      MEDELLIN       MEDELLIN SURORIENTAL -0.247381
# 3747615          BOYACA         TUNJA                  TUNJA SUR -0.519051
#
#          ET  BAJAS TOTAL
# 9         1            0
# 110       1            0
# 119       1            0
# 268       1            0
# 364       1            0
# ...      ..          ...
# 3746725   1            0
# 3746919   1            0
# 3747045   1            0
# 3747519   1            0
# 3747615   1            0
#
# [53792 rows x 90 columns]

# %%
data_causal[data_causal['ET']==1][seleccionVariables].sum().to_frame().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data_causal[data_causal['ET']==0][seleccionVariables].sum().to_frame().plot.bar()
# Out:
# <AxesSubplot:>

# %%
resumen_causa=data_causal[seleccionVariables].sum().to_frame()
resumen_causa=resumen_causa.merge(data_causal[data_causal['ET']==1][seleccionVariables].sum().to_frame(), left_index=True,right_index=True, how='left')
resumen_causa=resumen_causa.merge(data_causal[data_causal['ET']==0][seleccionVariables].sum().to_frame(), left_index=True,right_index=True, how='left')
resumen_causa.columns=['total','critico','normal']
resumen_causa
# Out:
#                              total  critico  normal
# CONGELACION                  17673        0   17673
# VIAJES                         554        0     554
# CAPACIDAD_DE_PAGO              201        0     201
# CAUSAS_EXTERNAS               1582        0    1582
# COMPETENCIA                      0        0       0
# MAL_SERVICIO                   313        0     313
# NO_UTILIZAR                   1631        0    1631
# NO_GUSTO                       514        0     514
# SIN_MOTIVO                     280        0     280
# SIN_CONTACTO                  4621        0    4621
# TRASLADOS                        0        0       0
# OTROS                          544        0     544
# CAMBIO_DE_SERVICIO               0        0       0
# CAMBIO_TARIFA                  269        0     269
# EMPAQUETAMIENTO                  0        0       0
# CESION_DE_CONTRATO               0        0       0
# UNIFICACION_EMPAQUETAMIENTO    199        0     199

# %%
x = resumen_causa.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
resumen_causa_nor = pd.DataFrame(x_scaled)
resumen_causa_nor.index=resumen_causa.index
resumen_causa_nor.columns=resumen_causa.columns
resumen_causa_nor=resumen_causa_nor.sort_values('total', ascending=False)
resumen_causa_nor
# Out:
#                                 total  critico    normal
# CONGELACION                  1.000000      0.0  1.000000
# SIN_CONTACTO                 0.261472      0.0  0.261472
# NO_UTILIZAR                  0.092288      0.0  0.092288
# CAUSAS_EXTERNAS              0.089515      0.0  0.089515
# VIAJES                       0.031347      0.0  0.031347
# OTROS                        0.030781      0.0  0.030781
# NO_GUSTO                     0.029084      0.0  0.029084
# MAL_SERVICIO                 0.017711      0.0  0.017711
# SIN_MOTIVO                   0.015843      0.0  0.015843
# CAMBIO_TARIFA                0.015221      0.0  0.015221
# CAPACIDAD_DE_PAGO            0.011373      0.0  0.011373
# UNIFICACION_EMPAQUETAMIENTO  0.011260      0.0  0.011260
# COMPETENCIA                  0.000000      0.0  0.000000
# TRASLADOS                    0.000000      0.0  0.000000
# CAMBIO_DE_SERVICIO           0.000000      0.0  0.000000
# EMPAQUETAMIENTO              0.000000      0.0  0.000000
# CESION_DE_CONTRATO           0.000000      0.0  0.000000

# %%
f = plt.figure()
resumen_causa_nor[['critico','normal']].plot.barh();
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
resumen_causa_nor['dif']=resumen_causa_nor['critico']-resumen_causa_nor['normal']

# %%
resumen_causa_nor=resumen_causa_nor.sort_values('dif', ascending=False)
resumen_causa_nor
# Out:
#                                 total  critico    normal       dif
# CESION_DE_CONTRATO           0.000000      0.0  0.000000  0.000000
# EMPAQUETAMIENTO              0.000000      0.0  0.000000  0.000000
# CAMBIO_DE_SERVICIO           0.000000      0.0  0.000000  0.000000
# TRASLADOS                    0.000000      0.0  0.000000  0.000000
# COMPETENCIA                  0.000000      0.0  0.000000  0.000000
# UNIFICACION_EMPAQUETAMIENTO  0.011260      0.0  0.011260 -0.011260
# CAPACIDAD_DE_PAGO            0.011373      0.0  0.011373 -0.011373
# CAMBIO_TARIFA                0.015221      0.0  0.015221 -0.015221
# SIN_MOTIVO                   0.015843      0.0  0.015843 -0.015843
# MAL_SERVICIO                 0.017711      0.0  0.017711 -0.017711
# NO_GUSTO                     0.029084      0.0  0.029084 -0.029084
# OTROS                        0.030781      0.0  0.030781 -0.030781
# VIAJES                       0.031347      0.0  0.031347 -0.031347
# CAUSAS_EXTERNAS              0.089515      0.0  0.089515 -0.089515
# NO_UTILIZAR                  0.092288      0.0  0.092288 -0.092288
# SIN_CONTACTO                 0.261472      0.0  0.261472 -0.261472
# CONGELACION                  1.000000      0.0  1.000000 -1.000000

# %%
# Diferencia entre críticos y normales
resumen_causa_nor[['dif']].plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## ARBOL

# %%
def visualizarArbol(model_fit,depth):
    fig, ax = plt.subplots(figsize=(depth*10,10))
    print(f"Profundidad del árbol: {tree_model.get_depth()}")
    print(f"Número de nodos terminales: {tree_model.get_n_leaves()}")
    plot = plot_tree(
                decision_tree = tree_model,
                feature_names = seleccionVariables,
                class_names   = ['normal','critico'],
                filled        = True,
                impurity      = False,
                fontsize      = 10,
                precision     = 3,
                ax            = ax
           )

# %%
tree_model = DecisionTreeClassifier(random_state=0, max_depth=5,min_samples_leaf=500, class_weight='balanced')
model_fit = tree_model.fit(X = data_causal[seleccionVariables], y = data_causal["ET"])
visualizarArbol(model_fit,3)
# Out:
# Profundidad del árbol: 5
# Número de nodos terminales: 6
